# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
batch_size = 4
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

data = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

train_indices = list(range(len(data)))[:40000]
validation_indices = list(range(len(data)))[40000:]

# train_sample = torch.utils.data.SubsetRandomSampler(train_indices)
# validation_sample = torch.utils.data.SubsetRandomSampler(validation_indices)


# Subsets of the whole train data using the sampled indices
trainset = torch.utils.data.Subset(data, train_indices)
validationset = torch.utils.data.Subset(data, train_indices)

# Dataloader using the created subsets
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

validationloader = torch.utils.data.DataLoader(validationset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)


testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print('Train set size: ', len(trainloader) * 4)
print('Validation set size: ', len(validationloader) * 4)
print('Test set size: ', len(testloader) * 4)
# Out:
# Train set size:  40000
# Validation set size:  40000
# Test set size:  10000

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Get some random training images.
dataiter = iter(trainloader)
images, labels = next(dataiter)
# Show images.
imshow(torchvision.utils.make_grid(images))
# Print labels.
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
#  ship   dog plane  bird

# %%
# Get some random valldation images.
dataiter = iter(validationloader)
images, labels = next(dataiter)
# Show images.
imshow(torchvision.utils.make_grid(images))
# Print labels.
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
#  ship   cat   dog horse

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %%
class NetMod(nn.Module):
    def __init__(self):
        super(NetMod, self).__init__()
        self.pool = nn.MaxPool2d(kernel_size=(2,2))
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=96, kernel_size=3, stride=1, padding=1)
        self.batchnorm1 = nn.BatchNorm2d(96)
        self.conv2 = nn.Conv2d(in_channels=96, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.batchnorm2 = nn.BatchNorm2d(256)
        self.conv3 = nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=1)
        self.batchnorm3 = nn.BatchNorm2d(384)
        self.conv4 = nn.Conv2d(in_channels=384, out_channels=384, kernel_size=3, stride=1, padding=1)
        self.batchnorm4 = nn.BatchNorm2d(384)
        self.conv5 = nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.batchnorm5 = nn.BatchNorm2d(256)
        self.fc1 = nn.Linear(in_features=256, out_features=256)
        self.fc2 = nn.Linear(in_features=256, out_features=256)
        self.fc3 = nn.Linear(in_features=256, out_features=10)
        
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.batchnorm1(x)
        x = self.pool(F.relu(self.conv2(x)))
        x = self.batchnorm2(x)
        x = self.pool(F.relu(self.conv3(x)))
        x = self.batchnorm3(x)
        x = self.pool(F.relu(self.conv4(x)))
        x = self.batchnorm4(x)
        x = self.pool(F.relu(self.conv5(x)))
        x = self.batchnorm5(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.fc2(F.relu(x))
        x = self.fc3(F.relu(x))
        x = F.relu(x)
        return x

net = NetMod()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# NetMod(
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv1): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=256, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss()  
# We use stochastic gradient descent (SGD) as optimizer.
opt = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, mode='min', patience=2, threshold=0.01, verbose=True)

# %%
avg_losses = []   # Avg. losses.
validation_losses = []
epochs = 90       # Total epochs.
print_freq = 2000  # Print frequency.
lr_list = set()

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_loss = 0.0       # Initialize running loss.
    validation_loss = 0.0
    
    net.train()
    for i, data in enumerate(trainloader, 0):
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step.
        outputs = net(inputs)
        loss = loss_func(outputs, labels)
        
        # Backward step.
        loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()

        # Print statistics.
        running_loss += loss.item()
        if i % print_freq == print_freq - 1: # Print every several mini-batches.
            avg_loss = running_loss / print_freq    
            print('[epoch: {}, i: {:5d}] avg mini-batch loss: {}'.format(
                epoch, i, avg_loss))
            avg_losses.append(avg_loss)
            running_loss = 0.0

    net.eval()
    with torch.no_grad():
        for i, data in enumerate(validationloader, 0):
            # Get the inputs.
            inputs, labels = data

            # Move the inputs to the specified device.
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward step.
            outputs = net(inputs)
            loss = loss_func(outputs, labels)
            validation_loss += loss.item()
            validation_losses.append(validation_loss)
    net.train()
    
    # If validation error no longer improve, divide the lr by 10
    scheduler.step(validation_loss)
    print('Validation Loss: ', validation_loss)
    lr_list.add(scheduler._last_lr[0])
                            

print('Finished Training.')
print('LR list: ', lr_list)
# Out:
# [epoch: 0, i:  1999] avg mini-batch loss: 1.9660970367789268
# [epoch: 0, i:  3999] avg mini-batch loss: 1.6764356264472007
# [epoch: 0, i:  5999] avg mini-batch loss: 1.5704693296775223
# [epoch: 0, i:  7999] avg mini-batch loss: 1.4708876583725214
# [epoch: 0, i:  9999] avg mini-batch loss: 1.4023574659600855
# Validation Loss:  12079.447311527096
# [epoch: 1, i:  1999] avg mini-batch loss: 1.3103752467259764
# [epoch: 1, i:  3999] avg mini-batch loss: 1.262191031485796
# [epoch: 1, i:  5999] avg mini-batch loss: 1.1448140057362617
# [epoch: 1, i:  7999] avg mini-batch loss: 1.1156115364152939
# [epoch: 1, i:  9999] avg mini-batch loss: 1.0772900836560875
# Validation Loss:  7634.300760407932
# [epoch: 2, i:  1999] avg mini-batch loss: 0.9441437990162521
# [epoch: 2, i:  3999] avg mini-batch loss: 0.9866852486412973
# [epoch: 2, i:  5999] avg mini-batch loss: 0.9539242966156453
# [epoch: 2, i:  7999] avg mini-batch loss: 0.9289130010399967
# [epoch: 2, i:  9999] avg mini-batch loss: 0.9327559400256723
# Validation Loss:  6256.62075765105
# [epoch: 3, i:  1999] avg mini-batch loss: 0.7953157909275033
# [epoch: 3, i:  3999] avg mini-batch loss: 0.8521170454067178
# [epoch: 3, i:  5999] avg mini-batch loss: 0.8419686641823501
# [epoch: 3, i:  7999] avg mini-batch loss: 0.8137007096605375
# [epoch: 3, i:  9999] avg mini-batch loss: 0.8265201648608781
# Validation Loss:  5135.761080052704
# [epoch: 4, i:  1999] avg mini-batch loss: 0.7050000052987598
# [epoch: 4, i:  3999] avg mini-batch loss: 0.729927442715969
# [epoch: 4, i:  5999] avg mini-batch loss: 0.7195383432758972
# [epoch: 4, i:  7999] avg mini-batch loss: 0.7481689223884604
# [epoch: 4, i:  9999] avg mini-batch loss: 0.753404988557566
# Validation Loss:  4513.915332730976
# [epoch: 5, i:  1999] avg mini-batch loss: 0.6262738080286654
# [epoch: 5, i:  3999] avg mini-batch loss: 0.6577505617730786
# [epoch: 5, i:  5999] avg mini-batch loss: 0.6539855550981593
# [epoch: 5, i:  7999] avg mini-batch loss: 0.6703372724482324
# [epoch: 5, i:  9999] avg mini-batch loss: 0.6720253737312741
# Validation Loss:  3548.941448963975
# [epoch: 6, i:  1999] avg mini-batch loss: 0.5505382312027505
# [epoch: 6, i:  3999] avg mini-batch loss: 0.5801684192335234
# [epoch: 6, i:  5999] avg mini-batch loss: 0.6123632108449237
# [epoch: 6, i:  7999] avg mini-batch loss: 0.6271350150234066
# [epoch: 6, i:  9999] avg mini-batch loss: 0.6497865698079113
# Validation Loss:  3567.3457725387125
# [epoch: 7, i:  1999] avg mini-batch loss: 0.5003438206353458
# [epoch: 7, i:  3999] avg mini-batch loss: 0.5159170137782348
# [epoch: 7, i:  5999] avg mini-batch loss: 0.5564379848553799
# [epoch: 7, i:  7999] avg mini-batch loss: 0.5742264749331516
# [epoch: 7, i:  9999] avg mini-batch loss: 0.5934415654198965
# Validation Loss:  2899.104228403303
# [epoch: 8, i:  1999] avg mini-batch loss: 0.4508473000655067
# [epoch: 8, i:  3999] avg mini-batch loss: 0.4864037119806744
# [epoch: 8, i:  5999] avg mini-batch loss: 0.5387035109540448
# [epoch: 8, i:  7999] avg mini-batch loss: 0.5246017168835387
# [epoch: 8, i:  9999] avg mini-batch loss: 0.5190039217802696
# Validation Loss:  2366.285334555014
# [epoch: 9, i:  1999] avg mini-batch loss: 0.39882162848475855
# [epoch: 9, i:  3999] avg mini-batch loss: 0.4587235242818715
# [epoch: 9, i:  5999] avg mini-batch loss: 0.49139823127439014
# [epoch: 9, i:  7999] avg mini-batch loss: 0.4906188613770064
# [epoch: 9, i:  9999] avg mini-batch loss: 0.5297775524108438
# Validation Loss:  2322.3958989390885
# [epoch: 10, i:  1999] avg mini-batch loss: 0.40212093664312853
# [epoch: 10, i:  3999] avg mini-batch loss: 0.4178605015790672
# [epoch: 10, i:  5999] avg mini-batch loss: 0.45746772006433456
# [epoch: 10, i:  7999] avg mini-batch loss: 0.49407388384011575
# [epoch: 10, i:  9999] avg mini-batch loss: 0.468162158865307
# Validation Loss:  2143.6638317107936
# [epoch: 11, i:  1999] avg mini-batch loss: 0.3514816255782207
# [epoch: 11, i:  3999] avg mini-batch loss: 0.40868069022335113
# [epoch: 11, i:  5999] avg mini-batch loss: 0.4309188066269271
# [epoch: 11, i:  7999] avg mini-batch loss: 0.460364923874964
# [epoch: 11, i:  9999] avg mini-batch loss: 0.4483798084763694
# Validation Loss:  2131.280263857687
# [epoch: 12, i:  1999] avg mini-batch loss: 0.35989946173282805
# [epoch: 12, i:  3999] avg mini-batch loss: 0.384373225702293
# [epoch: 12, i:  5999] avg mini-batch loss: 0.40394501464292987
# [epoch: 12, i:  7999] avg mini-batch loss: 0.44138152173673734
# [epoch: 12, i:  9999] avg mini-batch loss: 0.4422020819340833
# Validation Loss:  1987.8208036381293
# [epoch: 13, i:  1999] avg mini-batch loss: 0.329145348912949
# [epoch: 13, i:  3999] avg mini-batch loss: 0.37713505335434455
# [epoch: 13, i:  5999] avg mini-batch loss: 0.3964751187168586
# [epoch: 13, i:  7999] avg mini-batch loss: 0.41547817083695554
# [epoch: 13, i:  9999] avg mini-batch loss: 0.42143242127011765
# Validation Loss:  1724.2356209034388
# [epoch: 14, i:  1999] avg mini-batch loss: 0.32624366284749706
# [epoch: 14, i:  3999] avg mini-batch loss: 0.3621199303402682
# [epoch: 14, i:  5999] avg mini-batch loss: 0.38405595554588945
# [epoch: 14, i:  7999] avg mini-batch loss: 0.39481284209924344
# [epoch: 14, i:  9999] avg mini-batch loss: 0.41810017701296603
# Validation Loss:  1583.8532224021533
# [epoch: 15, i:  1999] avg mini-batch loss: 0.30169897611600754
# [epoch: 15, i:  3999] avg mini-batch loss: 0.3525640019686034
# [epoch: 15, i:  5999] avg mini-batch loss: 0.3626636344131839
# [epoch: 15, i:  7999] avg mini-batch loss: 0.3735501573760703
# [epoch: 15, i:  9999] avg mini-batch loss: 0.3960456195125007
# Validation Loss:  1479.8468098535686
# [epoch: 16, i:  1999] avg mini-batch loss: 0.28819981200099576
# [epoch: 16, i:  3999] avg mini-batch loss: 0.34951742497467786
# [epoch: 16, i:  5999] avg mini-batch loss: 0.371842228604306
# [epoch: 16, i:  7999] avg mini-batch loss: 0.3977225786048366
# [epoch: 16, i:  9999] avg mini-batch loss: 0.41256088583410017
# Validation Loss:  1538.0839309659787
# [epoch: 17, i:  1999] avg mini-batch loss: 0.29975933376393366
# [epoch: 17, i:  3999] avg mini-batch loss: 0.3138124728170806
# [epoch: 17, i:  5999] avg mini-batch loss: 0.35056901677462154
# [epoch: 17, i:  7999] avg mini-batch loss: 0.3820816967442515
# [epoch: 17, i:  9999] avg mini-batch loss: 0.3920093466888648
# Validation Loss:  1667.787025709329
# [epoch: 18, i:  1999] avg mini-batch loss: 0.2783682739617652
# [epoch: 18, i:  3999] avg mini-batch loss: 0.31093153717482347
# [epoch: 18, i:  5999] avg mini-batch loss: 0.34837364923089625
# [epoch: 18, i:  7999] avg mini-batch loss: 0.37025535585175384
# [epoch: 18, i:  9999] avg mini-batch loss: 0.3685368756619573
# Validation Loss:  1436.6889452841833
# [epoch: 19, i:  1999] avg mini-batch loss: 0.28269831312021415
# [epoch: 19, i:  3999] avg mini-batch loss: 0.31062292242023976
# [epoch: 19, i:  5999] avg mini-batch loss: 0.3584530091796769
# [epoch: 19, i:  7999] avg mini-batch loss: 0.3862443033650779
# [epoch: 19, i:  9999] avg mini-batch loss: 0.3823632399787166
# Validation Loss:  1398.9131868131626
# [epoch: 20, i:  1999] avg mini-batch loss: 0.27308662309279313
# [epoch: 20, i:  3999] avg mini-batch loss: 0.31453998620057244
# [epoch: 20, i:  5999] avg mini-batch loss: 0.32657869836007014
# [epoch: 20, i:  7999] avg mini-batch loss: 0.3580839141124452
# [epoch: 20, i:  9999] avg mini-batch loss: 0.36769448576885044
# Validation Loss:  1394.3118835234309
# [epoch: 21, i:  1999] avg mini-batch loss: 0.2757549683451653
# [epoch: 21, i:  3999] avg mini-batch loss: 0.2973614974308439
# [epoch: 21, i:  5999] avg mini-batch loss: 0.3373760267753969
# [epoch: 21, i:  7999] avg mini-batch loss: 0.37087763609248214
# [epoch: 21, i:  9999] avg mini-batch loss: 0.37921794472498005
# Validation Loss:  1305.7098819318744
# [epoch: 22, i:  1999] avg mini-batch loss: 0.26520369192340876
# [epoch: 22, i:  3999] avg mini-batch loss: 0.29410795071721074
# [epoch: 22, i:  5999] avg mini-batch loss: 0.3403557929566596
# [epoch: 22, i:  7999] avg mini-batch loss: 0.36714449503293145
# [epoch: 22, i:  9999] avg mini-batch loss: 0.3534494063178136
# Validation Loss:  1350.2750208705584
# [epoch: 23, i:  1999] avg mini-batch loss: 0.253031270392079
# [epoch: 23, i:  3999] avg mini-batch loss: 0.27063865413193705
# [epoch: 23, i:  5999] avg mini-batch loss: 0.33169631718826714
# [epoch: 23, i:  7999] avg mini-batch loss: 0.3413740030281042
# [epoch: 23, i:  9999] avg mini-batch loss: 0.36062634901949786
# Validation Loss:  1323.3487428830872
# [epoch: 24, i:  1999] avg mini-batch loss: 0.2737926420082804
# [epoch: 24, i:  3999] avg mini-batch loss: 0.289912806943903
# [epoch: 24, i:  5999] avg mini-batch loss: 0.3001091164251848
# [epoch: 24, i:  7999] avg mini-batch loss: 0.343381355014164
# [epoch: 24, i:  9999] avg mini-batch loss: 0.36069192444894
# Epoch 00025: reducing learning rate of group 0 to 1.0000e-04.
# Validation Loss:  1305.9633780838449
# [epoch: 25, i:  1999] avg mini-batch loss: 0.21145140542837906
# [epoch: 25, i:  3999] avg mini-batch loss: 0.17797035964918906
# [epoch: 25, i:  5999] avg mini-batch loss: 0.16981784146915016
# [epoch: 25, i:  7999] avg mini-batch loss: 0.15721473768162833
# [epoch: 25, i:  9999] avg mini-batch loss: 0.14992130740413268
# Validation Loss:  404.8734176948292
# [epoch: 26, i:  1999] avg mini-batch loss: 0.12028973770533775
# [epoch: 26, i:  3999] avg mini-batch loss: 0.11554026222957327
# [epoch: 26, i:  5999] avg mini-batch loss: 0.11953134442354349
# [epoch: 26, i:  7999] avg mini-batch loss: 0.10972080647130497
# [epoch: 26, i:  9999] avg mini-batch loss: 0.11290974851303326
# Validation Loss:  191.17680485569406
# [epoch: 27, i:  1999] avg mini-batch loss: 0.08471994959321455
# [epoch: 27, i:  3999] avg mini-batch loss: 0.08768056072362379
# [epoch: 27, i:  5999] avg mini-batch loss: 0.08951797415591137
# [epoch: 27, i:  7999] avg mini-batch loss: 0.0977817628026096
# [epoch: 27, i:  9999] avg mini-batch loss: 0.09649183616424124
# Validation Loss:  144.59182755115387
# [epoch: 28, i:  1999] avg mini-batch loss: 0.0872155168945901
# [epoch: 28, i:  3999] avg mini-batch loss: 0.07249354704536382
# [epoch: 28, i:  5999] avg mini-batch loss: 0.07678041650774503
# [epoch: 28, i:  7999] avg mini-batch loss: 0.07900824691706293
# [epoch: 28, i:  9999] avg mini-batch loss: 0.06972325164727954
# Validation Loss:  95.06667200344833
# [epoch: 29, i:  1999] avg mini-batch loss: 0.06743334511065405
# [epoch: 29, i:  3999] avg mini-batch loss: 0.06031931320121657
# [epoch: 29, i:  5999] avg mini-batch loss: 0.06749022419075845
# [epoch: 29, i:  7999] avg mini-batch loss: 0.06418567735277066
# [epoch: 29, i:  9999] avg mini-batch loss: 0.06503674225386204
# Validation Loss:  64.66695380384374
# [epoch: 30, i:  1999] avg mini-batch loss: 0.05569336797084361
# [epoch: 30, i:  3999] avg mini-batch loss: 0.058331737625765524
# [epoch: 30, i:  5999] avg mini-batch loss: 0.0557434706164513
# [epoch: 30, i:  7999] avg mini-batch loss: 0.05872827142647293
# [epoch: 30, i:  9999] avg mini-batch loss: 0.056067757544455164
# Validation Loss:  58.357227410694236
# [epoch: 31, i:  1999] avg mini-batch loss: 0.0581526987627185
# [epoch: 31, i:  3999] avg mini-batch loss: 0.05129503078752896
# [epoch: 31, i:  5999] avg mini-batch loss: 0.05264422011090755
# [epoch: 31, i:  7999] avg mini-batch loss: 0.053271571086587755
# [epoch: 31, i:  9999] avg mini-batch loss: 0.060408269444740655
# Validation Loss:  42.52404761041069
# [epoch: 32, i:  1999] avg mini-batch loss: 0.047637037066700944
# [epoch: 32, i:  3999] avg mini-batch loss: 0.05056777372359739
# [epoch: 32, i:  5999] avg mini-batch loss: 0.04649831374528912
# [epoch: 32, i:  7999] avg mini-batch loss: 0.04710402381466156
# [epoch: 32, i:  9999] avg mini-batch loss: 0.04775677053000982
# Validation Loss:  32.651716633616985
# [epoch: 33, i:  1999] avg mini-batch loss: 0.046188382662807274
# [epoch: 33, i:  3999] avg mini-batch loss: 0.046673414388405034
# [epoch: 33, i:  5999] avg mini-batch loss: 0.043301682058279764
# [epoch: 33, i:  7999] avg mini-batch loss: 0.04578856028329665
# [epoch: 33, i:  9999] avg mini-batch loss: 0.04550071997923442
# Validation Loss:  32.24364757384569
# [epoch: 34, i:  1999] avg mini-batch loss: 0.036585751048425666
# [epoch: 34, i:  3999] avg mini-batch loss: 0.03837742979786162
# [epoch: 34, i:  5999] avg mini-batch loss: 0.04372332295633805
# [epoch: 34, i:  7999] avg mini-batch loss: 0.04583642926160155
# [epoch: 34, i:  9999] avg mini-batch loss: 0.042779198579776676
# Validation Loss:  22.48255956361251
# [epoch: 35, i:  1999] avg mini-batch loss: 0.03879511275157165
# [epoch: 35, i:  3999] avg mini-batch loss: 0.042576690134557796
# [epoch: 35, i:  5999] avg mini-batch loss: 0.038812691719856046
# [epoch: 35, i:  7999] avg mini-batch loss: 0.04071166754502701
# [epoch: 35, i:  9999] avg mini-batch loss: 0.038265947809003595
# Validation Loss:  27.702031865154915
# [epoch: 36, i:  1999] avg mini-batch loss: 0.03547154013156251
# [epoch: 36, i:  3999] avg mini-batch loss: 0.03716088179797771
# [epoch: 36, i:  5999] avg mini-batch loss: 0.04053772837382894
# [epoch: 36, i:  7999] avg mini-batch loss: 0.03585758115817589
# [epoch: 36, i:  9999] avg mini-batch loss: 0.03315725300948361
# Validation Loss:  19.99912796237112
# [epoch: 37, i:  1999] avg mini-batch loss: 0.036579476623028316
# [epoch: 37, i:  3999] avg mini-batch loss: 0.036748320505816084
# [epoch: 37, i:  5999] avg mini-batch loss: 0.028908552838975993
# [epoch: 37, i:  7999] avg mini-batch loss: 0.03595956993708478
# [epoch: 37, i:  9999] avg mini-batch loss: 0.03279382086450824
# Validation Loss:  18.931527343685786
# [epoch: 38, i:  1999] avg mini-batch loss: 0.032503486083833195
# [epoch: 38, i:  3999] avg mini-batch loss: 0.03259448763166983
# [epoch: 38, i:  5999] avg mini-batch loss: 0.035871034223900096
# [epoch: 38, i:  7999] avg mini-batch loss: 0.02779497669259399
# [epoch: 38, i:  9999] avg mini-batch loss: 0.031117566606301807
# Validation Loss:  19.74830723999918
# [epoch: 39, i:  1999] avg mini-batch loss: 0.03303166593752758
# [epoch: 39, i:  3999] avg mini-batch loss: 0.03070366950679454
# [epoch: 39, i:  5999] avg mini-batch loss: 0.03652308905264363
# [epoch: 39, i:  7999] avg mini-batch loss: 0.0296323549810586
# [epoch: 39, i:  9999] avg mini-batch loss: 0.03257501573576428
# Validation Loss:  23.919403515201992
# [epoch: 40, i:  1999] avg mini-batch loss: 0.03127171444255145
# [epoch: 40, i:  3999] avg mini-batch loss: 0.03265887146466594
# [epoch: 40, i:  5999] avg mini-batch loss: 0.03212127955562209
# [epoch: 40, i:  7999] avg mini-batch loss: 0.0374322570805889
# [epoch: 40, i:  9999] avg mini-batch loss: 0.02985488382922631
# Validation Loss:  16.678485468406592
# [epoch: 41, i:  1999] avg mini-batch loss: 0.02766314094308018
# [epoch: 41, i:  3999] avg mini-batch loss: 0.031118144237089838
# [epoch: 41, i:  5999] avg mini-batch loss: 0.027391578807398217
# [epoch: 41, i:  7999] avg mini-batch loss: 0.026778959948481316
# [epoch: 41, i:  9999] avg mini-batch loss: 0.03172015269181793
# Validation Loss:  15.296187225616222
# [epoch: 42, i:  1999] avg mini-batch loss: 0.02724063929426302
# [epoch: 42, i:  3999] avg mini-batch loss: 0.029509214368858012
# [epoch: 42, i:  5999] avg mini-batch loss: 0.02541886227514169
# [epoch: 42, i:  7999] avg mini-batch loss: 0.02627091689997542
# [epoch: 42, i:  9999] avg mini-batch loss: 0.0340955088958217
# Validation Loss:  10.613830733660961
# [epoch: 43, i:  1999] avg mini-batch loss: 0.02649363871102196
# [epoch: 43, i:  3999] avg mini-batch loss: 0.02611353740129698
# [epoch: 43, i:  5999] avg mini-batch loss: 0.025816671022774244
# [epoch: 43, i:  7999] avg mini-batch loss: 0.026645084307563592
# [epoch: 43, i:  9999] avg mini-batch loss: 0.02464261061614161
# Validation Loss:  8.988737224122474
# [epoch: 44, i:  1999] avg mini-batch loss: 0.02416543607485164
# [epoch: 44, i:  3999] avg mini-batch loss: 0.028872677731161277
# [epoch: 44, i:  5999] avg mini-batch loss: 0.02561910635969798
# [epoch: 44, i:  7999] avg mini-batch loss: 0.0235331458276155
# [epoch: 44, i:  9999] avg mini-batch loss: 0.025502582723423983
# Validation Loss:  15.141999600299982
# [epoch: 45, i:  1999] avg mini-batch loss: 0.025500524084383868
# [epoch: 45, i:  3999] avg mini-batch loss: 0.025052578049489058
# [epoch: 45, i:  5999] avg mini-batch loss: 0.026777800782325358
# [epoch: 45, i:  7999] avg mini-batch loss: 0.02579149542972118
# [epoch: 45, i:  9999] avg mini-batch loss: 0.023131009939964316
# Validation Loss:  11.433608948952667
# [epoch: 46, i:  1999] avg mini-batch loss: 0.023571078769520682
# [epoch: 46, i:  3999] avg mini-batch loss: 0.024429873677419892
# [epoch: 46, i:  5999] avg mini-batch loss: 0.019529285036380316
# [epoch: 46, i:  7999] avg mini-batch loss: 0.024215094199288613
# [epoch: 46, i:  9999] avg mini-batch loss: 0.024481081425905358
# Epoch 00047: reducing learning rate of group 0 to 1.0000e-05.
# Validation Loss:  10.721072170364039
# [epoch: 47, i:  1999] avg mini-batch loss: 0.025852756201576087
# [epoch: 47, i:  3999] avg mini-batch loss: 0.025164127602092776
# [epoch: 47, i:  5999] avg mini-batch loss: 0.026092667250542944
# [epoch: 47, i:  7999] avg mini-batch loss: 0.029176365802984945
# [epoch: 47, i:  9999] avg mini-batch loss: 0.02075441095084261
# Validation Loss:  8.729877609331139
# [epoch: 48, i:  1999] avg mini-batch loss: 0.02334178866043112
# [epoch: 48, i:  3999] avg mini-batch loss: 0.022333666803156575
# [epoch: 48, i:  5999] avg mini-batch loss: 0.023034003761208625
# [epoch: 48, i:  7999] avg mini-batch loss: 0.024113609253265167
# [epoch: 48, i:  9999] avg mini-batch loss: 0.02343818950192872
# Validation Loss:  9.421133558422696
# [epoch: 49, i:  1999] avg mini-batch loss: 0.02265033472709729
# [epoch: 49, i:  3999] avg mini-batch loss: 0.023954510007752106
# [epoch: 49, i:  5999] avg mini-batch loss: 0.02077114337643161
# [epoch: 49, i:  7999] avg mini-batch loss: 0.02192361421745227
# [epoch: 49, i:  9999] avg mini-batch loss: 0.022739937576504415
# Validation Loss:  9.528212959939452
# [epoch: 50, i:  1999] avg mini-batch loss: 0.02457045997809291
# [epoch: 50, i:  3999] avg mini-batch loss: 0.024493871236664744
# [epoch: 50, i:  5999] avg mini-batch loss: 0.02253961624209387
# [epoch: 50, i:  7999] avg mini-batch loss: 0.022127322042549167
# [epoch: 50, i:  9999] avg mini-batch loss: 0.02163048816635455
# Epoch 00051: reducing learning rate of group 0 to 1.0000e-06.
# Validation Loss:  8.856611140460302
# [epoch: 51, i:  1999] avg mini-batch loss: 0.02480635003873249
# [epoch: 51, i:  3999] avg mini-batch loss: 0.023510713976969782
# [epoch: 51, i:  5999] avg mini-batch loss: 0.021938852442079222
# [epoch: 51, i:  7999] avg mini-batch loss: 0.02495766930147329
# [epoch: 51, i:  9999] avg mini-batch loss: 0.018848720614190826
# Validation Loss:  8.66660425136763
# [epoch: 52, i:  1999] avg mini-batch loss: 0.020749787354252477
# [epoch: 52, i:  3999] avg mini-batch loss: 0.01839540908354411
# [epoch: 52, i:  5999] avg mini-batch loss: 0.02368831863957439
# [epoch: 52, i:  7999] avg mini-batch loss: 0.022089578965579677
# [epoch: 52, i:  9999] avg mini-batch loss: 0.022464393457789812
# Validation Loss:  13.27445022936314
# [epoch: 53, i:  1999] avg mini-batch loss: 0.025208143576166547
# [epoch: 53, i:  3999] avg mini-batch loss: 0.018771857230544812
# [epoch: 53, i:  5999] avg mini-batch loss: 0.020433664516421233
# [epoch: 53, i:  7999] avg mini-batch loss: 0.023976922192036
# [epoch: 53, i:  9999] avg mini-batch loss: 0.023842476606738272
# Epoch 00054: reducing learning rate of group 0 to 1.0000e-07.
# Validation Loss:  13.102608343825946
# [epoch: 54, i:  1999] avg mini-batch loss: 0.023136250592043325
# [epoch: 54, i:  3999] avg mini-batch loss: 0.022946369904662787
# [epoch: 54, i:  5999] avg mini-batch loss: 0.022879587492021073
# [epoch: 54, i:  7999] avg mini-batch loss: 0.021486613883153042
# [epoch: 54, i:  9999] avg mini-batch loss: 0.02397972178179134
# Validation Loss:  8.197572688402602
# [epoch: 55, i:  1999] avg mini-batch loss: 0.02203808062924418
# [epoch: 55, i:  3999] avg mini-batch loss: 0.021765681990898882
# [epoch: 55, i:  5999] avg mini-batch loss: 0.02129375578134568
# [epoch: 55, i:  7999] avg mini-batch loss: 0.02172900677258349
# [epoch: 55, i:  9999] avg mini-batch loss: 0.020844931727146104
# Validation Loss:  11.064184400191436
# [epoch: 56, i:  1999] avg mini-batch loss: 0.021057164012785505
# [epoch: 56, i:  3999] avg mini-batch loss: 0.02193653503696987
# [epoch: 56, i:  5999] avg mini-batch loss: 0.02087571480290262
# [epoch: 56, i:  7999] avg mini-batch loss: 0.017612770469623684
# [epoch: 56, i:  9999] avg mini-batch loss: 0.01825910455473604
# Validation Loss:  6.83817227918351
# [epoch: 57, i:  1999] avg mini-batch loss: 0.0238517241168729
# [epoch: 57, i:  3999] avg mini-batch loss: 0.022796330746203238
# [epoch: 57, i:  5999] avg mini-batch loss: 0.02131830554964199
# [epoch: 57, i:  7999] avg mini-batch loss: 0.017435848475061903
# [epoch: 57, i:  9999] avg mini-batch loss: 0.019996057973931784
# Validation Loss:  9.12303864465548
# [epoch: 58, i:  1999] avg mini-batch loss: 0.02627641065471016
# [epoch: 58, i:  3999] avg mini-batch loss: 0.023503202416753084
# [epoch: 58, i:  5999] avg mini-batch loss: 0.019615376967381054
# [epoch: 58, i:  7999] avg mini-batch loss: 0.02077636476482212
# [epoch: 58, i:  9999] avg mini-batch loss: 0.022692880237008467
# Validation Loss:  6.923546113384873
# [epoch: 59, i:  1999] avg mini-batch loss: 0.021924433395184677
# [epoch: 59, i:  3999] avg mini-batch loss: 0.020950324519603783
# [epoch: 59, i:  5999] avg mini-batch loss: 0.021525624155523473
# [epoch: 59, i:  7999] avg mini-batch loss: 0.01995515048710513
# [epoch: 59, i:  9999] avg mini-batch loss: 0.022430478430743278
# Epoch 00060: reducing learning rate of group 0 to 1.0000e-08.
# Validation Loss:  10.497930220237322
# [epoch: 60, i:  1999] avg mini-batch loss: 0.021876272743625576
# [epoch: 60, i:  3999] avg mini-batch loss: 0.019448155084895006
# [epoch: 60, i:  5999] avg mini-batch loss: 0.02364056126064952
# [epoch: 60, i:  7999] avg mini-batch loss: 0.023676123439353432
# [epoch: 60, i:  9999] avg mini-batch loss: 0.023253924022104
# Validation Loss:  7.088771101243253
# [epoch: 61, i:  1999] avg mini-batch loss: 0.020482569169460476
# [epoch: 61, i:  3999] avg mini-batch loss: 0.021786697520256894
# [epoch: 61, i:  5999] avg mini-batch loss: 0.023521071926427793
# [epoch: 61, i:  7999] avg mini-batch loss: 0.021976346103900143
# [epoch: 61, i:  9999] avg mini-batch loss: 0.023384969888611523
# Validation Loss:  9.304892740356053
# [epoch: 62, i:  1999] avg mini-batch loss: 0.027672532474833134
# [epoch: 62, i:  3999] avg mini-batch loss: 0.019899472571304613
# [epoch: 62, i:  5999] avg mini-batch loss: 0.022637292690958474
# [epoch: 62, i:  7999] avg mini-batch loss: 0.017825483987008738
# [epoch: 62, i:  9999] avg mini-batch loss: 0.01988639543419413
# Validation Loss:  11.753313351073757
# [epoch: 63, i:  1999] avg mini-batch loss: 0.020412897967777097
# [epoch: 63, i:  3999] avg mini-batch loss: 0.02055229917910492
# [epoch: 63, i:  5999] avg mini-batch loss: 0.021011380443867893
# [epoch: 63, i:  7999] avg mini-batch loss: 0.020211956806682793
# [epoch: 63, i:  9999] avg mini-batch loss: 0.023341736981858048
# Validation Loss:  9.896508576329865
# [epoch: 64, i:  1999] avg mini-batch loss: 0.020386554660151886
# [epoch: 64, i:  3999] avg mini-batch loss: 0.02409346479895339
# [epoch: 64, i:  5999] avg mini-batch loss: 0.020693125928461995
# [epoch: 64, i:  7999] avg mini-batch loss: 0.022867357560274287
# [epoch: 64, i:  9999] avg mini-batch loss: 0.01871377157740153
# Validation Loss:  7.567007120334978
# [epoch: 65, i:  1999] avg mini-batch loss: 0.019447148019550695
# [epoch: 65, i:  3999] avg mini-batch loss: 0.023666203663919076
# [epoch: 65, i:  5999] avg mini-batch loss: 0.019044846668224636
# [epoch: 65, i:  7999] avg mini-batch loss: 0.021660494647805534
# [epoch: 65, i:  9999] avg mini-batch loss: 0.021618818921428102
# Validation Loss:  12.785065686158418
# [epoch: 66, i:  1999] avg mini-batch loss: 0.019203072678761146
# [epoch: 66, i:  3999] avg mini-batch loss: 0.01813801500876889
# [epoch: 66, i:  5999] avg mini-batch loss: 0.019837336852105182
# [epoch: 66, i:  7999] avg mini-batch loss: 0.022486812512031974
# [epoch: 66, i:  9999] avg mini-batch loss: 0.025373710489973746
# Validation Loss:  8.500966551667545
# [epoch: 67, i:  1999] avg mini-batch loss: 0.023199135988630586
# [epoch: 67, i:  3999] avg mini-batch loss: 0.024526940011181067
# [epoch: 67, i:  5999] avg mini-batch loss: 0.020920030946861515
# [epoch: 67, i:  7999] avg mini-batch loss: 0.021206505807196664
# [epoch: 67, i:  9999] avg mini-batch loss: 0.018103763808730945
# Validation Loss:  10.51292360553154
# [epoch: 68, i:  1999] avg mini-batch loss: 0.02235594498406408
# [epoch: 68, i:  3999] avg mini-batch loss: 0.024344684447251894
# [epoch: 68, i:  5999] avg mini-batch loss: 0.023917164965465417
# [epoch: 68, i:  7999] avg mini-batch loss: 0.021026064056347424
# [epoch: 68, i:  9999] avg mini-batch loss: 0.017849836620896894
# Validation Loss:  9.834374340071804
# [epoch: 69, i:  1999] avg mini-batch loss: 0.023841783060705894
# [epoch: 69, i:  3999] avg mini-batch loss: 0.02564704554463151
# [epoch: 69, i:  5999] avg mini-batch loss: 0.022843285540262513
# [epoch: 69, i:  7999] avg mini-batch loss: 0.021718806700774623
# [epoch: 69, i:  9999] avg mini-batch loss: 0.02128233479251503
# Validation Loss:  8.393219173869426
# [epoch: 70, i:  1999] avg mini-batch loss: 0.0224934684320242
# [epoch: 70, i:  3999] avg mini-batch loss: 0.022927331508709813
# [epoch: 70, i:  5999] avg mini-batch loss: 0.019164873699065537
# [epoch: 70, i:  7999] avg mini-batch loss: 0.02129000789922884
# [epoch: 70, i:  9999] avg mini-batch loss: 0.01999929201975192
# Validation Loss:  7.104022088350945
# [epoch: 71, i:  1999] avg mini-batch loss: 0.022045559963751658
# [epoch: 71, i:  3999] avg mini-batch loss: 0.021286168153657855
# [epoch: 71, i:  5999] avg mini-batch loss: 0.0212028370614089
# [epoch: 71, i:  7999] avg mini-batch loss: 0.02126690621790749
# [epoch: 71, i:  9999] avg mini-batch loss: 0.02010201666179546
# Validation Loss:  10.503554879750311
# [epoch: 72, i:  1999] avg mini-batch loss: 0.020176358016680752
# [epoch: 72, i:  3999] avg mini-batch loss: 0.01690277955007059
# [epoch: 72, i:  5999] avg mini-batch loss: 0.022600147719624146
# [epoch: 72, i:  7999] avg mini-batch loss: 0.022252135016185094
# [epoch: 72, i:  9999] avg mini-batch loss: 0.023609034859943676
# Validation Loss:  11.139826802448312
# [epoch: 73, i:  1999] avg mini-batch loss: 0.02272965217561341
# [epoch: 73, i:  3999] avg mini-batch loss: 0.02051830639623995
# [epoch: 73, i:  5999] avg mini-batch loss: 0.021042650098450393
# [epoch: 73, i:  7999] avg mini-batch loss: 0.024600594306697532
# [epoch: 73, i:  9999] avg mini-batch loss: 0.024271410153880426
# Validation Loss:  8.040091813413369
# [epoch: 74, i:  1999] avg mini-batch loss: 0.02699272737278534
# [epoch: 74, i:  3999] avg mini-batch loss: 0.02232558254298965
# [epoch: 74, i:  5999] avg mini-batch loss: 0.023201436616836872
# [epoch: 74, i:  7999] avg mini-batch loss: 0.02215845156098658
# [epoch: 74, i:  9999] avg mini-batch loss: 0.02001429719612497
# Validation Loss:  7.778365602290961
# [epoch: 75, i:  1999] avg mini-batch loss: 0.018570681700427485
# [epoch: 75, i:  3999] avg mini-batch loss: 0.023504774589329827
# [epoch: 75, i:  5999] avg mini-batch loss: 0.023786028707302648
# [epoch: 75, i:  7999] avg mini-batch loss: 0.022774899764546715
# [epoch: 75, i:  9999] avg mini-batch loss: 0.024620046612884836
# Validation Loss:  8.322183655319563
# [epoch: 76, i:  1999] avg mini-batch loss: 0.020684761014414108
# [epoch: 76, i:  3999] avg mini-batch loss: 0.021054033544914093
# [epoch: 76, i:  5999] avg mini-batch loss: 0.01914937339647304
# [epoch: 76, i:  7999] avg mini-batch loss: 0.019263327486236447
# [epoch: 76, i:  9999] avg mini-batch loss: 0.024982893920257994
# Validation Loss:  9.77525513858268
# [epoch: 77, i:  1999] avg mini-batch loss: 0.02123404164943895
# [epoch: 77, i:  3999] avg mini-batch loss: 0.024587927523879442
# [epoch: 77, i:  5999] avg mini-batch loss: 0.02397583646295061
# [epoch: 77, i:  7999] avg mini-batch loss: 0.025315416158621703
# [epoch: 77, i:  9999] avg mini-batch loss: 0.02281793344343623
# Validation Loss:  7.405249643354921
# [epoch: 78, i:  1999] avg mini-batch loss: 0.020343949694210096
# [epoch: 78, i:  3999] avg mini-batch loss: 0.019329221526830226
# [epoch: 78, i:  5999] avg mini-batch loss: 0.02165452442957212
# [epoch: 78, i:  7999] avg mini-batch loss: 0.019833377055456368
# [epoch: 78, i:  9999] avg mini-batch loss: 0.026765628441973603
# Validation Loss:  11.444299068349551
# [epoch: 79, i:  1999] avg mini-batch loss: 0.021654850711778636
# [epoch: 79, i:  3999] avg mini-batch loss: 0.020617108752750937
# [epoch: 79, i:  5999] avg mini-batch loss: 0.023066802492715397
# [epoch: 79, i:  7999] avg mini-batch loss: 0.021382969014683114
# [epoch: 79, i:  9999] avg mini-batch loss: 0.02216729007865615
# Validation Loss:  10.1967807961218
# [epoch: 80, i:  1999] avg mini-batch loss: 0.02148847520189338
# [epoch: 80, i:  3999] avg mini-batch loss: 0.022060670983852105
# [epoch: 80, i:  5999] avg mini-batch loss: 0.022064764201759318
# [epoch: 80, i:  7999] avg mini-batch loss: 0.020614082996812614
# [epoch: 80, i:  9999] avg mini-batch loss: 0.020628855441819725
# Validation Loss:  8.98011599757426
# [epoch: 81, i:  1999] avg mini-batch loss: 0.0226788296432087
# [epoch: 81, i:  3999] avg mini-batch loss: 0.02090699444868369
# [epoch: 81, i:  5999] avg mini-batch loss: 0.021078923070094787
# [epoch: 81, i:  7999] avg mini-batch loss: 0.022469650715236638
# [epoch: 81, i:  9999] avg mini-batch loss: 0.022210003653388412
# Validation Loss:  8.913833815958931
# [epoch: 82, i:  1999] avg mini-batch loss: 0.02147155894237858
# [epoch: 82, i:  3999] avg mini-batch loss: 0.019744767299781415
# [epoch: 82, i:  5999] avg mini-batch loss: 0.020834073796178017
# [epoch: 82, i:  7999] avg mini-batch loss: 0.020755101066584302
# [epoch: 82, i:  9999] avg mini-batch loss: 0.02195125539208857
# Validation Loss:  8.36158898637592
# [epoch: 83, i:  1999] avg mini-batch loss: 0.026655251225911343
# [epoch: 83, i:  3999] avg mini-batch loss: 0.018271200170794144
# [epoch: 83, i:  5999] avg mini-batch loss: 0.0192918900469449
# [epoch: 83, i:  7999] avg mini-batch loss: 0.019382065892397805
# [epoch: 83, i:  9999] avg mini-batch loss: 0.02204649377640817
# Validation Loss:  9.546530391385488
# [epoch: 84, i:  1999] avg mini-batch loss: 0.02142703138749539
# [epoch: 84, i:  3999] avg mini-batch loss: 0.023452673286384198
# [epoch: 84, i:  5999] avg mini-batch loss: 0.019824711982141707
# [epoch: 84, i:  7999] avg mini-batch loss: 0.018542337422506536
# [epoch: 84, i:  9999] avg mini-batch loss: 0.024234650790227533
# Validation Loss:  6.569721136185393
# [epoch: 85, i:  1999] avg mini-batch loss: 0.02276802199532085
# [epoch: 85, i:  3999] avg mini-batch loss: 0.02039877711279678
# [epoch: 85, i:  5999] avg mini-batch loss: 0.018931732010887572
# [epoch: 85, i:  7999] avg mini-batch loss: 0.021355180211034167
# [epoch: 85, i:  9999] avg mini-batch loss: 0.020628231487731682
# Validation Loss:  11.047229211249627
# [epoch: 86, i:  1999] avg mini-batch loss: 0.022212126111488942
# [epoch: 86, i:  3999] avg mini-batch loss: 0.021349101302655982
# [epoch: 86, i:  5999] avg mini-batch loss: 0.02258387610927639
# [epoch: 86, i:  7999] avg mini-batch loss: 0.02101012380593056
# [epoch: 86, i:  9999] avg mini-batch loss: 0.023710996724625146
# Validation Loss:  9.450950328360307
# [epoch: 87, i:  1999] avg mini-batch loss: 0.023932859060816554
# [epoch: 87, i:  3999] avg mini-batch loss: 0.019018299793014195
# [epoch: 87, i:  5999] avg mini-batch loss: 0.018382737527792414
# [epoch: 87, i:  7999] avg mini-batch loss: 0.017719882714763116
# [epoch: 87, i:  9999] avg mini-batch loss: 0.019232876204848252
# Validation Loss:  8.468560492078595
# [epoch: 88, i:  1999] avg mini-batch loss: 0.02041106874772777
# [epoch: 88, i:  3999] avg mini-batch loss: 0.02230690168534238
# [epoch: 88, i:  5999] avg mini-batch loss: 0.02204450444282793
# [epoch: 88, i:  7999] avg mini-batch loss: 0.020917842808004024
# [epoch: 88, i:  9999] avg mini-batch loss: 0.022613646440659066
# Validation Loss:  7.68411391373251
# [epoch: 89, i:  1999] avg mini-batch loss: 0.02110349227732513
# [epoch: 89, i:  3999] avg mini-batch loss: 0.02169146630557407
# [epoch: 89, i:  5999] avg mini-batch loss: 0.02484795351648654
# [epoch: 89, i:  7999] avg mini-batch loss: 0.0196277592682045
# [epoch: 89, i:  9999] avg mini-batch loss: 0.020181512539857522
# Validation Loss:  8.779233457684825
# Finished Training.
# LR list:  {1e-05, 1.0000000000000002e-07, 1.0000000000000004e-08, 0.0001, 1.0000000000000002e-06, 0.001}

# %%
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
# Check several images.
dataiter = iter(testloader)
images, labels = next(dataiter)
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
outputs = net(images.to(device))
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(batch_size)))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat   car  ship plane

# %%
# Get test accuracy.
correct = 0
total = 0

net.eval()
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

net.train()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 82 %

# %%
# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(batch_size):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 82 %
# Accuracy of   car : 89 %
# Accuracy of  bird : 72 %
# Accuracy of   cat : 61 %
# Accuracy of  deer : 77 %
# Accuracy of   dog : 70 %
# Accuracy of  frog : 83 %
# Accuracy of horse : 82 %
# Accuracy of  ship : 88 %
# Accuracy of truck : 88 %
