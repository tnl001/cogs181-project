# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
batch_size = 4
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

data = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

train_indices = list(range(len(data)))[:40000]
validation_indices = list(range(len(data)))[40000:]

# train_sample = torch.utils.data.SubsetRandomSampler(train_indices)
# validation_sample = torch.utils.data.SubsetRandomSampler(validation_indices)


# Subsets of the whole train data using the sampled indices
trainset = torch.utils.data.Subset(data, train_indices)
validationset = torch.utils.data.Subset(data, validation_indices)

# Dataloader using the created subsets
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

validationloader = torch.utils.data.DataLoader(validationset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)


testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print('Train set size: ', len(trainloader) * 4)
print('Validation set size: ', len(validationloader) * 4)
print('Test set size: ', len(testloader) * 4)
# Out:
# Train set size:  40000
# Validation set size:  10000
# Test set size:  10000

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Get some random training images.
dataiter = iter(trainloader)
images, labels = next(dataiter)
# Show images.
imshow(torchvision.utils.make_grid(images))
# Print labels.
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
# plane   dog truck   car

# %%
# Get some random valldation images.
dataiter = iter(validationloader)
images, labels = next(dataiter)
# Show images.
imshow(torchvision.utils.make_grid(images))
# Print labels.
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
#  frog truck  frog horse

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %%
class NetMod(nn.Module):
    def __init__(self):
        super(NetMod, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=96, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=(2,2))
        self.conv2 = nn.Conv2d(in_channels=96, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(in_channels=384, out_channels=384, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(in_features=256, out_features=256)
        self.fc2 = nn.Linear(in_features=256, out_features=256)
        self.fc3 = nn.Linear(in_features=256, out_features=10)
        self.dropout = nn.Dropout(p=0.5)
        
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = self.pool(F.relu(self.conv4(x)))
        x = self.pool(F.relu(self.conv5(x)))
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.dropout(x)
        x = self.fc2(F.relu(x))
        x = self.dropout(x)
        x = self.fc3(F.relu(x))
        x = F.relu(x)
        return x

net = NetMod()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# NetMod(
#   (conv1): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=256, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss()  
# We use stochastic gradient descent (SGD) as optimizer.
opt = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0005)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, mode='min', patience=2, threshold=0.01, verbose=True)

# %%
avg_losses = []   # Avg. losses.
validation_losses = []
train_losses = []
epochs = 30       # Total epochs.
print_freq = 2000  # Print frequency.
lr_list = set()

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_loss = 0.0       # Initialize running loss.
    validation_loss = 0.0
    train_loss = 0.0
    
    net.train()
    for i, data in enumerate(trainloader, 0):
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step.
        outputs = net(inputs)
        loss = loss_func(outputs, labels)
        
        # Backward step.
        loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()

        # Print statistics.
        running_loss += loss.item()
        train_loss += loss.item()
        if i % print_freq == print_freq - 1: # Print every several mini-batches.
            avg_loss = running_loss / print_freq    
            print('[epoch: {}, i: {:5d}] avg mini-batch loss: {}'.format(
                epoch, i, avg_loss))
            avg_losses.append(avg_loss)
            running_loss = 0.0

    net.eval()
    with torch.no_grad():
        for i, data in enumerate(validationloader, 0):
            # Get the inputs.
            inputs, labels = data

            # Move the inputs to the specified device.
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward step.
            outputs = net(inputs)
            loss = loss_func(outputs, labels)
            validation_loss += loss.item()
    net.train()
    
    # If validation error no longer improve, divide the lr by 10
    scheduler.step(validation_loss)
    print('Validation Loss: ', validation_loss, '----', 'Train Loss: ', train_loss)
    validation_losses.append(validation_loss)
    train_losses.append(train_loss)
    lr_list.add(scheduler._last_lr[0])
                            

print('Finished Training.')
print('LR list: ', lr_list)
# Out:
# [epoch: 0, i:  1999] avg mini-batch loss: 2.3028697381019594
# [epoch: 0, i:  3999] avg mini-batch loss: 2.302606773376465
# [epoch: 0, i:  5999] avg mini-batch loss: 2.302681706905365
# [epoch: 0, i:  7999] avg mini-batch loss: 2.302646268606186
# [epoch: 0, i:  9999] avg mini-batch loss: 2.3026113196611404
# Validation Loss:  5756.462812423706 ---- Train Loss:  23026.83161330223
# [epoch: 1, i:  1999] avg mini-batch loss: 2.302554168343544
# [epoch: 1, i:  3999] avg mini-batch loss: 2.302637135028839
# [epoch: 1, i:  5999] avg mini-batch loss: 2.302330955862999
# [epoch: 1, i:  7999] avg mini-batch loss: 2.3027078824043272
# [epoch: 1, i:  9999] avg mini-batch loss: 2.3025360788106917
# Validation Loss:  5755.923234701157 ---- Train Loss:  23025.532440900803
# [epoch: 2, i:  1999] avg mini-batch loss: 2.302295094013214
# [epoch: 2, i:  3999] avg mini-batch loss: 2.30250080370903
# [epoch: 2, i:  5999] avg mini-batch loss: 2.3015362879037857
# [epoch: 2, i:  7999] avg mini-batch loss: 2.299096067070961
# [epoch: 2, i:  9999] avg mini-batch loss: 2.2796706563830376
# Validation Loss:  5547.913495063782 ---- Train Loss:  22970.197818160057
# [epoch: 3, i:  1999] avg mini-batch loss: 2.149228794813156
# [epoch: 3, i:  3999] avg mini-batch loss: 2.0814622784256933
# [epoch: 3, i:  5999] avg mini-batch loss: 2.0117854695916177
# [epoch: 3, i:  7999] avg mini-batch loss: 1.90222174346447
# [epoch: 3, i:  9999] avg mini-batch loss: 1.8346283585727214
# Validation Loss:  4300.164819359779 ---- Train Loss:  19958.653289735317
# [epoch: 4, i:  1999] avg mini-batch loss: 1.7564161438047885
# [epoch: 4, i:  3999] avg mini-batch loss: 1.6901109461784363
# [epoch: 4, i:  5999] avg mini-batch loss: 1.6432231377214193
# [epoch: 4, i:  7999] avg mini-batch loss: 1.5801696273982524
# [epoch: 4, i:  9999] avg mini-batch loss: 1.5019739951193332
# Validation Loss:  3516.677503556013 ---- Train Loss:  16343.78770044446
# [epoch: 5, i:  1999] avg mini-batch loss: 1.4175782074257732
# [epoch: 5, i:  3999] avg mini-batch loss: 1.3390465827435256
# [epoch: 5, i:  5999] avg mini-batch loss: 1.3001789864636957
# [epoch: 5, i:  7999] avg mini-batch loss: 1.238918485581875
# [epoch: 5, i:  9999] avg mini-batch loss: 1.1988505678065122
# Validation Loss:  2941.7020274177194 ---- Train Loss:  12989.145660042763
# [epoch: 6, i:  1999] avg mini-batch loss: 1.1175042124204337
# [epoch: 6, i:  3999] avg mini-batch loss: 1.0927381238266827
# [epoch: 6, i:  5999] avg mini-batch loss: 1.0617145975651219
# [epoch: 6, i:  7999] avg mini-batch loss: 1.024313799350988
# [epoch: 6, i:  9999] avg mini-batch loss: 0.9923808421404101
# Validation Loss:  2390.7015315862373 ---- Train Loss:  10577.303150607273
# [epoch: 7, i:  1999] avg mini-batch loss: 0.9005886310809292
# [epoch: 7, i:  3999] avg mini-batch loss: 0.9092849540645257
# [epoch: 7, i:  5999] avg mini-batch loss: 0.8722849208903499
# [epoch: 7, i:  7999] avg mini-batch loss: 0.8646400935035199
# [epoch: 7, i:  9999] avg mini-batch loss: 0.8552071786352899
# Validation Loss:  2026.0990100745112 ---- Train Loss:  8804.011556349229
# [epoch: 8, i:  1999] avg mini-batch loss: 0.7375419654424767
# [epoch: 8, i:  3999] avg mini-batch loss: 0.7482543372596847
# [epoch: 8, i:  5999] avg mini-batch loss: 0.7423293100567535
# [epoch: 8, i:  7999] avg mini-batch loss: 0.7395604427175713
# [epoch: 8, i:  9999] avg mini-batch loss: 0.7652311978163198
# Validation Loss:  1953.786816218868 ---- Train Loss:  7465.834506585612
# [epoch: 9, i:  1999] avg mini-batch loss: 0.5966340835676601
# [epoch: 9, i:  3999] avg mini-batch loss: 0.6115836855554371
# [epoch: 9, i:  5999] avg mini-batch loss: 0.6189439773730991
# [epoch: 9, i:  7999] avg mini-batch loss: 0.638614917730185
# [epoch: 9, i:  9999] avg mini-batch loss: 0.6426205358588195
# Validation Loss:  1833.668956714624 ---- Train Loss:  6216.794400170402
# [epoch: 10, i:  1999] avg mini-batch loss: 0.49394511121376855
# [epoch: 10, i:  3999] avg mini-batch loss: 0.5227668356891664
# [epoch: 10, i:  5999] avg mini-batch loss: 0.5435385749962297
# [epoch: 10, i:  7999] avg mini-batch loss: 0.5391130753371399
# [epoch: 10, i:  9999] avg mini-batch loss: 0.5262998697188159
# Validation Loss:  1917.3383416728175 ---- Train Loss:  5251.326933910241
# [epoch: 11, i:  1999] avg mini-batch loss: 0.3977548666178336
# [epoch: 11, i:  3999] avg mini-batch loss: 0.441125371634007
# [epoch: 11, i:  5999] avg mini-batch loss: 0.4323294488834108
# [epoch: 11, i:  7999] avg mini-batch loss: 0.45376023147830713
# [epoch: 11, i:  9999] avg mini-batch loss: 0.4539568897761019
# Validation Loss:  1906.3554566880266 ---- Train Loss:  4357.853616779321
# [epoch: 12, i:  1999] avg mini-batch loss: 0.33121499313640923
# [epoch: 12, i:  3999] avg mini-batch loss: 0.35291819607132674
# [epoch: 12, i:  5999] avg mini-batch loss: 0.37111422200491506
# [epoch: 12, i:  7999] avg mini-batch loss: 0.3938377043668779
# [epoch: 12, i:  9999] avg mini-batch loss: 0.3826373634493063
# Epoch 00013: reducing learning rate of group 0 to 1.0000e-04.
# Validation Loss:  1899.6977687337385 ---- Train Loss:  3663.4449580576706
# [epoch: 13, i:  1999] avg mini-batch loss: 0.18945644363038877
# [epoch: 13, i:  3999] avg mini-batch loss: 0.15012379586672114
# [epoch: 13, i:  5999] avg mini-batch loss: 0.14624381581223295
# [epoch: 13, i:  7999] avg mini-batch loss: 0.13896380529029465
# [epoch: 13, i:  9999] avg mini-batch loss: 0.13126020048147968
# Validation Loss:  1742.6737879481102 ---- Train Loss:  1512.0961221622342
# [epoch: 14, i:  1999] avg mini-batch loss: 0.09225697315322562
# [epoch: 14, i:  3999] avg mini-batch loss: 0.0903851489606873
# [epoch: 14, i:  5999] avg mini-batch loss: 0.0930358062426601
# [epoch: 14, i:  7999] avg mini-batch loss: 0.08830953871282565
# [epoch: 14, i:  9999] avg mini-batch loss: 0.07858422136466565
# Validation Loss:  1867.624208285617 ---- Train Loss:  885.1433768681286
# [epoch: 15, i:  1999] avg mini-batch loss: 0.06366213569433057
# [epoch: 15, i:  3999] avg mini-batch loss: 0.05562101162344959
# [epoch: 15, i:  5999] avg mini-batch loss: 0.059306220680413836
# [epoch: 15, i:  7999] avg mini-batch loss: 0.06156457078187003
# [epoch: 15, i:  9999] avg mini-batch loss: 0.05644150780564172
# Validation Loss:  1981.3153769375765 ---- Train Loss:  593.1908931714115
# [epoch: 16, i:  1999] avg mini-batch loss: 0.04769510500360238
# [epoch: 16, i:  3999] avg mini-batch loss: 0.04146934160386874
# [epoch: 16, i:  5999] avg mini-batch loss: 0.04415314976962105
# [epoch: 16, i:  7999] avg mini-batch loss: 0.04157078860472439
# [epoch: 16, i:  9999] avg mini-batch loss: 0.045620129931154885
# Epoch 00017: reducing learning rate of group 0 to 1.0000e-05.
# Validation Loss:  2092.1359116757867 ---- Train Loss:  441.0170298259429
# [epoch: 17, i:  1999] avg mini-batch loss: 0.031020013547473767
# [epoch: 17, i:  3999] avg mini-batch loss: 0.029708705442558398
# [epoch: 17, i:  5999] avg mini-batch loss: 0.030393341717268554
# [epoch: 17, i:  7999] avg mini-batch loss: 0.036360365782065515
# [epoch: 17, i:  9999] avg mini-batch loss: 0.03040799144942688
# Validation Loss:  2094.266885501467 ---- Train Loss:  315.78083587758624
# [epoch: 18, i:  1999] avg mini-batch loss: 0.028532301328579264
# [epoch: 18, i:  3999] avg mini-batch loss: 0.029508043825157232
# [epoch: 18, i:  5999] avg mini-batch loss: 0.030906585283843584
# [epoch: 18, i:  7999] avg mini-batch loss: 0.03090219766541096
# [epoch: 18, i:  9999] avg mini-batch loss: 0.028629423270615278
# Validation Loss:  2115.864775297729 ---- Train Loss:  296.9571027472126
# [epoch: 19, i:  1999] avg mini-batch loss: 0.031356660633594234
# [epoch: 19, i:  3999] avg mini-batch loss: 0.028145269498500235
# [epoch: 19, i:  5999] avg mini-batch loss: 0.031036008029411043
# [epoch: 19, i:  7999] avg mini-batch loss: 0.029103863941553024
# [epoch: 19, i:  9999] avg mini-batch loss: 0.025620043563712898
# Epoch 00020: reducing learning rate of group 0 to 1.0000e-06.
# Validation Loss:  2136.0855579073186 ---- Train Loss:  290.52369133354284
# [epoch: 20, i:  1999] avg mini-batch loss: 0.0241341900024856
# [epoch: 20, i:  3999] avg mini-batch loss: 0.026096576003836164
# [epoch: 20, i:  5999] avg mini-batch loss: 0.027664526171949796
# [epoch: 20, i:  7999] avg mini-batch loss: 0.031254498602065535
# [epoch: 20, i:  9999] avg mini-batch loss: 0.027175699133658308
# Validation Loss:  2137.583342892088 ---- Train Loss:  272.6509798279908
# [epoch: 21, i:  1999] avg mini-batch loss: 0.028518063485651994
# [epoch: 21, i:  3999] avg mini-batch loss: 0.02959866976679575
# [epoch: 21, i:  5999] avg mini-batch loss: 0.027894862923487963
# [epoch: 21, i:  7999] avg mini-batch loss: 0.02826431868654771
# [epoch: 21, i:  9999] avg mini-batch loss: 0.026085301547832233
# Validation Loss:  2138.7816447244254 ---- Train Loss:  280.72243282063135
# [epoch: 22, i:  1999] avg mini-batch loss: 0.02734310102290136
# [epoch: 22, i:  3999] avg mini-batch loss: 0.02846954756420653
# [epoch: 22, i:  5999] avg mini-batch loss: 0.02707810413644572
# [epoch: 22, i:  7999] avg mini-batch loss: 0.02226792492423856
# [epoch: 22, i:  9999] avg mini-batch loss: 0.031160852635418162
# Epoch 00023: reducing learning rate of group 0 to 1.0000e-07.
# Validation Loss:  2139.6654114098774 ---- Train Loss:  272.6390605664207
# [epoch: 23, i:  1999] avg mini-batch loss: 0.026506152770654844
# [epoch: 23, i:  3999] avg mini-batch loss: 0.029773125880747278
# [epoch: 23, i:  5999] avg mini-batch loss: 0.02497859556384613
# [epoch: 23, i:  7999] avg mini-batch loss: 0.02595605232961418
# [epoch: 23, i:  9999] avg mini-batch loss: 0.02632236908797284
# Validation Loss:  2139.6140018044034 ---- Train Loss:  267.07259126567055
# [epoch: 24, i:  1999] avg mini-batch loss: 0.031480407162774185
# [epoch: 24, i:  3999] avg mini-batch loss: 0.025889034819433485
# [epoch: 24, i:  5999] avg mini-batch loss: 0.026864164458006403
# [epoch: 24, i:  7999] avg mini-batch loss: 0.024443654348544962
# [epoch: 24, i:  9999] avg mini-batch loss: 0.026958692077661637
# Validation Loss:  2139.559096539284 ---- Train Loss:  271.27190573284145
# [epoch: 25, i:  1999] avg mini-batch loss: 0.027469426421177418
# [epoch: 25, i:  3999] avg mini-batch loss: 0.030692431288172763
# [epoch: 25, i:  5999] avg mini-batch loss: 0.024497228599474632
# [epoch: 25, i:  7999] avg mini-batch loss: 0.02839675874760539
# [epoch: 25, i:  9999] avg mini-batch loss: 0.026469202400174717
# Epoch 00026: reducing learning rate of group 0 to 1.0000e-08.
# Validation Loss:  2139.482907935125 ---- Train Loss:  275.0500949132098
# [epoch: 26, i:  1999] avg mini-batch loss: 0.02958971066586361
# [epoch: 26, i:  3999] avg mini-batch loss: 0.025327943779528496
# [epoch: 26, i:  5999] avg mini-batch loss: 0.026478822064585145
# [epoch: 26, i:  7999] avg mini-batch loss: 0.03041088671707282
# [epoch: 26, i:  9999] avg mini-batch loss: 0.025419220280709823
# Validation Loss:  2139.4761685860703 ---- Train Loss:  274.4531670155198
# [epoch: 27, i:  1999] avg mini-batch loss: 0.03047581240291806
# [epoch: 27, i:  3999] avg mini-batch loss: 0.029719213017618488
# [epoch: 27, i:  5999] avg mini-batch loss: 0.02673180146587987
# [epoch: 27, i:  7999] avg mini-batch loss: 0.02488607048644448
# [epoch: 27, i:  9999] avg mini-batch loss: 0.025885618629244555
# Validation Loss:  2139.47019592506 ---- Train Loss:  275.3970320042109
# [epoch: 28, i:  1999] avg mini-batch loss: 0.02959288789234591
# [epoch: 28, i:  3999] avg mini-batch loss: 0.028800344507462508
# [epoch: 28, i:  5999] avg mini-batch loss: 0.0261595538112879
# [epoch: 28, i:  7999] avg mini-batch loss: 0.02519666373735116
# [epoch: 28, i:  9999] avg mini-batch loss: 0.024374553811222832
# Validation Loss:  2139.46551767713 ---- Train Loss:  268.24800751934066
# [epoch: 29, i:  1999] avg mini-batch loss: 0.028603489954204066
# [epoch: 29, i:  3999] avg mini-batch loss: 0.02683673200384098
# [epoch: 29, i:  5999] avg mini-batch loss: 0.030234890214023345
# [epoch: 29, i:  7999] avg mini-batch loss: 0.025732738276719958
# [epoch: 29, i:  9999] avg mini-batch loss: 0.027004567129732045
# Validation Loss:  2139.459895316392 ---- Train Loss:  276.8248351570408
# Finished Training.
# LR list:  {1e-05, 1.0000000000000002e-07, 1.0000000000000004e-08, 0.0001, 1.0000000000000002e-06, 0.001}

# %%
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
plt.plot(validation_losses)
plt.xlabel('epoch')
plt.ylabel('losses')
plt.show()

# %%
plt.plot(train_losses)
plt.xlabel('epoch')
plt.ylabel('losses')
plt.show()

# %%
# Check several images.
net.eval()
with torch.no_grad():
    dataiter = iter(testloader)
    images, labels = next(dataiter)
    imshow(torchvision.utils.make_grid(images))
    print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
    outputs = net(images.to(device))
    _, predicted = torch.max(outputs, 1)

    print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                                  for j in range(batch_size)))
net.train()
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    cat  ship  ship plane
# NetMod(
#   (conv1): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=256, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Get test accuracy.
correct = 0
total = 0

net.eval()
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

net.train()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 80 %

# %%
# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(batch_size):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 83 %
# Accuracy of   car : 89 %
# Accuracy of  bird : 72 %
# Accuracy of   cat : 62 %
# Accuracy of  deer : 78 %
# Accuracy of   dog : 71 %
# Accuracy of  frog : 86 %
# Accuracy of horse : 83 %
# Accuracy of  ship : 89 %
# Accuracy of truck : 87 %
