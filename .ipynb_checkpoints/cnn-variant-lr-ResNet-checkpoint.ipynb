# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
batch_size = 4
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

data = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

train_indices = list(range(len(data)))[:40000]
validation_indices = list(range(len(data)))[40000:]

# train_sample = torch.utils.data.SubsetRandomSampler(train_indices)
# validation_sample = torch.utils.data.SubsetRandomSampler(validation_indices)


# Subsets of the whole train data using the sampled indices
trainset = torch.utils.data.Subset(data, train_indices)
validationset = torch.utils.data.Subset(data, validation_indices)

# Dataloader using the created subsets
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

validationloader = torch.utils.data.DataLoader(validationset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)


testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
len(validationset)
# Out:
# 10000

# %%
print('Train set size: ', len(trainloader) * 4)
print('Validation set size: ', len(validationloader) * 4)
print('Test set size: ', len(testloader) * 4)
# Out:
# Train set size:  40000
# Validation set size:  10000
# Test set size:  10000

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Get some random training images.
dataiter = iter(trainloader)
images, labels = next(dataiter)
# Show images.
imshow(torchvision.utils.make_grid(images))
# Print labels.
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
#  frog  bird plane plane

# %%
# Get some random valldation images.
dataiter = iter(validationloader)
images, labels = next(dataiter)
# Show images.
imshow(torchvision.utils.make_grid(images))
# Print labels.
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
# truck  bird   car horse

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %%
class NetMod(nn.Module):
    def __init__(self):
        super(NetMod, self).__init__()
        self.avgpool = nn.AvgPool2d(kernel_size=(8,8))
        
        self.filter1 = 16
        self.filter2 = 32
        self.filter3 = 64
        
        self.convinit = nn.Conv2d(in_channels=3, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        
        self.conv1 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        
        self.conv7 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter2, kernel_size=3, stride=2, padding=1)
        self.conv8 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter2, kernel_size=3, stride=1, padding=1)
        self.conv9 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter2, kernel_size=3, stride=1, padding=1)
        self.conv10 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter2, kernel_size=3, stride=1, padding=1)
        self.conv11 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter2, kernel_size=3, stride=1, padding=1)
        self.conv12 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter2, kernel_size=3, stride=1, padding=1)
        
        self.conv13 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter3, kernel_size=3, stride=2, padding=1)
        self.conv14 = nn.Conv2d(in_channels=self.filter3, out_channels=self.filter3, kernel_size=3, stride=1, padding=1)
        self.conv15 = nn.Conv2d(in_channels=self.filter3, out_channels=self.filter3, kernel_size=3, stride=1, padding=1)
        self.conv16 = nn.Conv2d(in_channels=self.filter3, out_channels=self.filter3, kernel_size=3, stride=1, padding=1)
        self.conv17 = nn.Conv2d(in_channels=self.filter3, out_channels=self.filter3, kernel_size=3, stride=1, padding=1)
        self.conv18 = nn.Conv2d(in_channels=self.filter3, out_channels=self.filter3, kernel_size=3, stride=1, padding=1)
        
        self.batchnorm1 = nn.BatchNorm2d(self.filter1)
        self.batchnorm2 = nn.BatchNorm2d(self.filter2)
        self.batchnorm3 = nn.BatchNorm2d(self.filter3)
        
        self.fc1 = nn.Linear(in_features=self.filter3, out_features=10)
        
    def forward(self, x):
        ##### n = 3
        ##### first 3x3 conv layer
        x = self.convinit(x)
        x = self.batchnorm1(x)
        x = F.relu(x)
        
        ##### 2n layers for 32x32 features
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = F.relu(x)
        
        x = self.conv2(x)
        x = self.batchnorm1(x)
        x = F.relu(x)
        
        x = self.conv3(x)
        x = self.batchnorm1(x)
        x = F.relu(x)
        
        x = self.conv4(x)
        x = self.batchnorm1(x)
        x = F.relu(x)
        
        x = self.conv5(x)
        x = self.batchnorm1(x)
        x = F.relu(x)
        
        x = self.conv6(x)
        x = self.batchnorm1(x)
        x = F.relu(x)
        
        ##### 2n layers for 16x16 features
        x = self.conv7(x)
        x = self.batchnorm2(x)
        x = F.relu(x)
        
        x = self.conv8(x)
        x = self.batchnorm2(x)
        x = F.relu(x)
        
        x = self.conv9(x)
        x = self.batchnorm2(x)
        x = F.relu(x)
        
        x = self.conv10(x)
        x = self.batchnorm2(x)
        x = F.relu(x)
        
        x = self.conv11(x)
        x = self.batchnorm2(x)
        x = F.relu(x)
        
        x = self.conv12(x)
        x = self.batchnorm2(x)
        x = F.relu(x)
        
        #### 2n layers for 8x8 features
        x = self.conv13(x)
        x = self.batchnorm3(x)
        x = F.relu(x)
        
        x = self.conv14(x)
        x = self.batchnorm3(x)
        x = F.relu(x)
        
        x = self.conv15(x)
        x = self.batchnorm3(x)
        x = F.relu(x)
        
        x = self.conv16(x)
        x = self.batchnorm3(x)
        x = F.relu(x)
        
        x = self.conv17(x)
        x = self.batchnorm3(x)
        x = F.relu(x)
        
        x = self.conv18(x)
        x = self.batchnorm3(x)
        x = F.relu(x)
        
        # avg pool and linear layer
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        return x

net = NetMod()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# NetMod(
#   (avgpool): AvgPool2d(kernel_size=(8, 8), stride=(8, 8), padding=0)
#   (convinit): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv6): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv7): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv8): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv10): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv12): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv13): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv17): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv18): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss()  
# We use stochastic gradient descent (SGD) as optimizer.
opt = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, weight_decay=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, mode='min', patience=2, threshold=0.01, verbose=True)

# %%
avg_losses = []   # Avg. losses.
validation_losses = []
epochs = 10       # Total epochs.
print_freq = 100  # Print frequency.
lr_list = set()
valid_losses = []

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_loss = 0.0       # Initialize running loss.
    validation_loss = 0.0
    
    net.train()
    for i, data in enumerate(trainloader, 0):
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step.
        outputs = net(inputs)
        loss = loss_func(outputs, labels)
        
        # Backward step.
        loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()

        # Print statistics.
        running_loss += loss.item()
        if i % print_freq == print_freq - 1: # Print every several mini-batches.
            avg_loss = running_loss / print_freq    
            print('[epoch: {}, i: {:5d}] avg mini-batch loss: {}'.format(
                epoch, i, avg_loss))
            avg_losses.append(avg_loss)
            running_loss = 0.0

    net.eval()
    with torch.no_grad():
        for i, data in enumerate(validationloader, 0):
            # Get the inputs.
            inputs, labels = data

            # Move the inputs to the specified device.
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward step.
            outputs = net(inputs)
            loss = loss_func(outputs, labels)
            validation_loss += loss.item()
            validation_losses.append(validation_loss)
    net.train()
    
    # If validation error no longer improve, divide the lr by 10
    scheduler.step(validation_loss)
    print('Validation Loss: ', validation_loss)
    valid_losses.append(validation_loss)
    lr_list.add(scheduler._last_lr[0])
                            

print('Finished Training.')
print('LR list: ', lr_list)
# Out:
# [epoch: 0, i:    99] avg mini-batch loss: 2.3982962453365326
# [epoch: 0, i:   199] avg mini-batch loss: 2.3275383710861206
# [epoch: 0, i:   299] avg mini-batch loss: 2.357361023426056
# [epoch: 0, i:   399] avg mini-batch loss: 2.326549721956253
# [epoch: 0, i:   499] avg mini-batch loss: 2.3276468646526336
# [epoch: 0, i:   599] avg mini-batch loss: 2.334735884666443
# [epoch: 0, i:   699] avg mini-batch loss: 2.367459752559662
# [epoch: 0, i:   799] avg mini-batch loss: 2.350970469713211
# [epoch: 0, i:   899] avg mini-batch loss: 2.317108815908432
# [epoch: 0, i:   999] avg mini-batch loss: 2.332654891014099
# [epoch: 0, i:  1099] avg mini-batch loss: 2.31910494685173
# [epoch: 0, i:  1199] avg mini-batch loss: 2.3397857677936553
# [epoch: 0, i:  1299] avg mini-batch loss: 2.2963860511779783
# [epoch: 0, i:  1399] avg mini-batch loss: 2.2713605308532716
# [epoch: 0, i:  1499] avg mini-batch loss: 2.3324914419651033
# [epoch: 0, i:  1599] avg mini-batch loss: 2.330605707168579
# [epoch: 0, i:  1699] avg mini-batch loss: 2.2833036017417907
# [epoch: 0, i:  1799] avg mini-batch loss: 2.31670956492424
# [epoch: 0, i:  1899] avg mini-batch loss: 2.279731113910675
# [epoch: 0, i:  1999] avg mini-batch loss: 2.256589696407318
# [epoch: 0, i:  2099] avg mini-batch loss: 2.2364146173000337
# [epoch: 0, i:  2199] avg mini-batch loss: 2.2453046679496764
# [epoch: 0, i:  2299] avg mini-batch loss: 2.2326618897914887
# [epoch: 0, i:  2399] avg mini-batch loss: 2.273437465429306
# [epoch: 0, i:  2499] avg mini-batch loss: 2.2475764203071593
# [epoch: 0, i:  2599] avg mini-batch loss: 2.2102868854999542
# [epoch: 0, i:  2699] avg mini-batch loss: 2.2673077428340913
# [epoch: 0, i:  2799] avg mini-batch loss: 2.2098089766502382
# [epoch: 0, i:  2899] avg mini-batch loss: 2.240505726337433
# [epoch: 0, i:  2999] avg mini-batch loss: 2.245637900829315
# [epoch: 0, i:  3099] avg mini-batch loss: 2.2165261936187743
# [epoch: 0, i:  3199] avg mini-batch loss: 2.244332537651062
# [epoch: 0, i:  3299] avg mini-batch loss: 2.230901510715485
# [epoch: 0, i:  3399] avg mini-batch loss: 2.1882380199432374
# [epoch: 0, i:  3499] avg mini-batch loss: 2.2604929220676424
# [epoch: 0, i:  3599] avg mini-batch loss: 2.188468496799469
# [epoch: 0, i:  3699] avg mini-batch loss: 2.2424581623077393
# [epoch: 0, i:  3799] avg mini-batch loss: 2.1891624319553373
# [epoch: 0, i:  3899] avg mini-batch loss: 2.165081627368927
# [epoch: 0, i:  3999] avg mini-batch loss: 2.176577389240265
# [epoch: 0, i:  4099] avg mini-batch loss: 2.1334587001800536
# [epoch: 0, i:  4199] avg mini-batch loss: 2.1601327252388
# [epoch: 0, i:  4299] avg mini-batch loss: 2.1544239032268524
# [epoch: 0, i:  4399] avg mini-batch loss: 2.1402104651927947
# [epoch: 0, i:  4499] avg mini-batch loss: 2.1302045941352845
# [epoch: 0, i:  4599] avg mini-batch loss: 2.1473268365859983
# [epoch: 0, i:  4699] avg mini-batch loss: 2.118467302322388
# [epoch: 0, i:  4799] avg mini-batch loss: 2.160369610786438
# [epoch: 0, i:  4899] avg mini-batch loss: 2.1811882352828977
# [epoch: 0, i:  4999] avg mini-batch loss: 2.1934616816043855
# [epoch: 0, i:  5099] avg mini-batch loss: 2.161412341594696
# [epoch: 0, i:  5199] avg mini-batch loss: 2.175860815048218
# [epoch: 0, i:  5299] avg mini-batch loss: 2.1434978711605073
# [epoch: 0, i:  5399] avg mini-batch loss: 2.150201703310013
# [epoch: 0, i:  5499] avg mini-batch loss: 2.1357810592651365
# [epoch: 0, i:  5599] avg mini-batch loss: 2.1273734974861145
# [epoch: 0, i:  5699] avg mini-batch loss: 2.1802238857746126
# [epoch: 0, i:  5799] avg mini-batch loss: 2.1244200479984285
# [epoch: 0, i:  5899] avg mini-batch loss: 2.169406999349594
# [epoch: 0, i:  5999] avg mini-batch loss: 2.1377729880809784
# [epoch: 0, i:  6099] avg mini-batch loss: 2.1060000646114347
# [epoch: 0, i:  6199] avg mini-batch loss: 2.1071689248085024
# [epoch: 0, i:  6299] avg mini-batch loss: 2.111242598295212
# [epoch: 0, i:  6399] avg mini-batch loss: 2.118139954805374
# [epoch: 0, i:  6499] avg mini-batch loss: 2.0976253390312194
# [epoch: 0, i:  6599] avg mini-batch loss: 2.1234680581092835
# [epoch: 0, i:  6699] avg mini-batch loss: 2.1211984634399412
# [epoch: 0, i:  6799] avg mini-batch loss: 2.078494999408722
# [epoch: 0, i:  6899] avg mini-batch loss: 2.0738174295425416
# [epoch: 0, i:  6999] avg mini-batch loss: 2.0641656386852265
# [epoch: 0, i:  7099] avg mini-batch loss: 2.1196813583374023
# [epoch: 0, i:  7199] avg mini-batch loss: 2.0840043592453004
# [epoch: 0, i:  7299] avg mini-batch loss: 2.1526050889492034
# [epoch: 0, i:  7399] avg mini-batch loss: 2.0413663351535796
# [epoch: 0, i:  7499] avg mini-batch loss: 2.0959800803661346
# [epoch: 0, i:  7599] avg mini-batch loss: 2.1660225224494933
# [epoch: 0, i:  7699] avg mini-batch loss: 2.1285749566555023
# [epoch: 0, i:  7799] avg mini-batch loss: 2.1135893177986147
# [epoch: 0, i:  7899] avg mini-batch loss: 2.0522760772705078
# [epoch: 0, i:  7999] avg mini-batch loss: 2.1206408131122587
# [epoch: 0, i:  8099] avg mini-batch loss: 2.1502440094947817
# [epoch: 0, i:  8199] avg mini-batch loss: 2.092841432094574
# [epoch: 0, i:  8299] avg mini-batch loss: 2.0020586705207823
# [epoch: 0, i:  8399] avg mini-batch loss: 2.057924542427063
# [epoch: 0, i:  8499] avg mini-batch loss: 2.0864655780792236
# [epoch: 0, i:  8599] avg mini-batch loss: 2.1044986176490785
# [epoch: 0, i:  8699] avg mini-batch loss: 2.034993529319763
# [epoch: 0, i:  8799] avg mini-batch loss: 2.0744222807884216
# [epoch: 0, i:  8899] avg mini-batch loss: 2.100963258743286
# [epoch: 0, i:  8999] avg mini-batch loss: 2.0740164422988894
# [epoch: 0, i:  9099] avg mini-batch loss: 2.077594791650772
# [epoch: 0, i:  9199] avg mini-batch loss: 2.018773592710495
# [epoch: 0, i:  9299] avg mini-batch loss: 2.09423534989357
# [epoch: 0, i:  9399] avg mini-batch loss: 2.0253464806079866
# [epoch: 0, i:  9499] avg mini-batch loss: 2.10991063952446
# [epoch: 0, i:  9599] avg mini-batch loss: 1.9819059336185456
# [epoch: 0, i:  9699] avg mini-batch loss: 2.1548134088516235
# [epoch: 0, i:  9799] avg mini-batch loss: 2.062604851722717
# [epoch: 0, i:  9899] avg mini-batch loss: 2.0692329955101014
# [epoch: 0, i:  9999] avg mini-batch loss: 2.093151264190674
# Validation Loss:  105749.6639919281
# [epoch: 1, i:    99] avg mini-batch loss: 2.01106956243515
# [epoch: 1, i:   199] avg mini-batch loss: 2.0798307061195374
# [epoch: 1, i:   299] avg mini-batch loss: 2.115684047937393
# [epoch: 1, i:   399] avg mini-batch loss: 1.9780969774723054
# [epoch: 1, i:   499] avg mini-batch loss: 1.9556097888946533
# [epoch: 1, i:   599] avg mini-batch loss: 2.047605413198471
# [epoch: 1, i:   699] avg mini-batch loss: 2.037722227573395
# [epoch: 1, i:   799] avg mini-batch loss: 2.1274039793014525
# [epoch: 1, i:   899] avg mini-batch loss: 2.0736992073059084
# [epoch: 1, i:   999] avg mini-batch loss: 2.041762504577637
# [epoch: 1, i:  1099] avg mini-batch loss: 1.9832080900669098
# [epoch: 1, i:  1199] avg mini-batch loss: 2.033363779783249
# [epoch: 1, i:  1299] avg mini-batch loss: 1.99335284948349
# [epoch: 1, i:  1399] avg mini-batch loss: 1.9938670897483826
# [epoch: 1, i:  1499] avg mini-batch loss: 1.9657707214355469
# [epoch: 1, i:  1599] avg mini-batch loss: 2.0216105043888093
# [epoch: 1, i:  1699] avg mini-batch loss: 2.033453015089035
# [epoch: 1, i:  1799] avg mini-batch loss: 2.0368297052383424
# [epoch: 1, i:  1899] avg mini-batch loss: 1.9630182826519011
# [epoch: 1, i:  1999] avg mini-batch loss: 2.033033186197281
# [epoch: 1, i:  2099] avg mini-batch loss: 2.0121945428848265
# [epoch: 1, i:  2199] avg mini-batch loss: 2.1285723876953124
# [epoch: 1, i:  2299] avg mini-batch loss: 1.965921756029129
# [epoch: 1, i:  2399] avg mini-batch loss: 2.0068106496334077
# [epoch: 1, i:  2499] avg mini-batch loss: 2.0084110724925996
# [epoch: 1, i:  2599] avg mini-batch loss: 2.022909151315689
# [epoch: 1, i:  2699] avg mini-batch loss: 2.0249355137348175
# [epoch: 1, i:  2799] avg mini-batch loss: 2.0498848330974577
# [epoch: 1, i:  2899] avg mini-batch loss: 2.052845051288605
# [epoch: 1, i:  2999] avg mini-batch loss: 1.9510435557365418
# [epoch: 1, i:  3099] avg mini-batch loss: 2.023486930131912
# [epoch: 1, i:  3199] avg mini-batch loss: 1.9548405277729035
# [epoch: 1, i:  3299] avg mini-batch loss: 2.0140986335277558
# [epoch: 1, i:  3399] avg mini-batch loss: 1.9471920776367186
# [epoch: 1, i:  3499] avg mini-batch loss: 1.9401074105501175
# [epoch: 1, i:  3599] avg mini-batch loss: 1.9546357321739196
# [epoch: 1, i:  3699] avg mini-batch loss: 1.9362570524215699
# [epoch: 1, i:  3799] avg mini-batch loss: 1.9982675457000731
# [epoch: 1, i:  3899] avg mini-batch loss: 2.0495970702171324
# [epoch: 1, i:  3999] avg mini-batch loss: 2.0020930230617524
# [epoch: 1, i:  4099] avg mini-batch loss: 2.0282978868484496
# [epoch: 1, i:  4199] avg mini-batch loss: 1.9898567974567414
# [epoch: 1, i:  4299] avg mini-batch loss: 1.9686146020889281
# [epoch: 1, i:  4399] avg mini-batch loss: 2.0145605993270874
# [epoch: 1, i:  4499] avg mini-batch loss: 1.9300706887245178
# [epoch: 1, i:  4599] avg mini-batch loss: 1.9924437737464904
# [epoch: 1, i:  4699] avg mini-batch loss: 1.9756175184249878
# [epoch: 1, i:  4799] avg mini-batch loss: 1.9535880893468858
# [epoch: 1, i:  4899] avg mini-batch loss: 2.021314842700958
# [epoch: 1, i:  4999] avg mini-batch loss: 1.943381311893463
# [epoch: 1, i:  5099] avg mini-batch loss: 1.9949457037448883
# [epoch: 1, i:  5199] avg mini-batch loss: 1.9571919560432434
# [epoch: 1, i:  5299] avg mini-batch loss: 1.9965269577503204
# [epoch: 1, i:  5399] avg mini-batch loss: 1.9152651250362396
# [epoch: 1, i:  5499] avg mini-batch loss: 1.9902558636665344
# [epoch: 1, i:  5599] avg mini-batch loss: 2.0162039959430693
# [epoch: 1, i:  5699] avg mini-batch loss: 1.908163993358612
# [epoch: 1, i:  5799] avg mini-batch loss: 2.0022020399570466
# [epoch: 1, i:  5899] avg mini-batch loss: 2.009677373170853
# [epoch: 1, i:  5999] avg mini-batch loss: 1.9698673069477082
# [epoch: 1, i:  6099] avg mini-batch loss: 1.9351898586750031
# [epoch: 1, i:  6199] avg mini-batch loss: 1.9599011719226838
# [epoch: 1, i:  6299] avg mini-batch loss: 1.9020428609848024
# [epoch: 1, i:  6399] avg mini-batch loss: 2.015374087095261
# [epoch: 1, i:  6499] avg mini-batch loss: 1.9955850291252135
# [epoch: 1, i:  6599] avg mini-batch loss: 1.9263780725002289
# [epoch: 1, i:  6699] avg mini-batch loss: 1.9838556694984435
# [epoch: 1, i:  6799] avg mini-batch loss: 2.0048624753952025
# [epoch: 1, i:  6899] avg mini-batch loss: 1.9625096714496613
# [epoch: 1, i:  6999] avg mini-batch loss: 1.9706764459609984
# [epoch: 1, i:  7099] avg mini-batch loss: 1.9519894671440126
# [epoch: 1, i:  7199] avg mini-batch loss: 1.9819029974937439
# [epoch: 1, i:  7299] avg mini-batch loss: 2.012757225036621
# [epoch: 1, i:  7399] avg mini-batch loss: 2.0216892272233964
# [epoch: 1, i:  7499] avg mini-batch loss: 1.9440505111217499
# [epoch: 1, i:  7599] avg mini-batch loss: 2.022603373527527
# [epoch: 1, i:  7699] avg mini-batch loss: 1.9814422619342804
# [epoch: 1, i:  7799] avg mini-batch loss: 2.0365807390213013
# [epoch: 1, i:  7899] avg mini-batch loss: 1.9555074381828308
# [epoch: 1, i:  7999] avg mini-batch loss: 1.9769378685951233
# [epoch: 1, i:  8099] avg mini-batch loss: 1.9088948798179626
# [epoch: 1, i:  8199] avg mini-batch loss: 1.9345530956983565
# [epoch: 1, i:  8299] avg mini-batch loss: 2.0690891802310944
# [epoch: 1, i:  8399] avg mini-batch loss: 2.029282153248787
# [epoch: 1, i:  8499] avg mini-batch loss: 1.9503414142131805
# [epoch: 1, i:  8599] avg mini-batch loss: 1.9711847805976868
# [epoch: 1, i:  8699] avg mini-batch loss: 1.9789769268035888
# [epoch: 1, i:  8799] avg mini-batch loss: 1.926655797958374
# [epoch: 1, i:  8899] avg mini-batch loss: 1.914749589562416
# [epoch: 1, i:  8999] avg mini-batch loss: 1.9577136147022247
# [epoch: 1, i:  9099] avg mini-batch loss: 1.9530491054058075
# [epoch: 1, i:  9199] avg mini-batch loss: 1.9304748833179475
# [epoch: 1, i:  9299] avg mini-batch loss: 1.9762706995010375
# [epoch: 1, i:  9399] avg mini-batch loss: 1.9559733998775481
# [epoch: 1, i:  9499] avg mini-batch loss: 1.9197821426391601
# [epoch: 1, i:  9599] avg mini-batch loss: 1.9152599835395814
# [epoch: 1, i:  9699] avg mini-batch loss: 1.9490219414234162
# [epoch: 1, i:  9799] avg mini-batch loss: 1.843535112142563
# [epoch: 1, i:  9899] avg mini-batch loss: 1.9010316109657288
# [epoch: 1, i:  9999] avg mini-batch loss: 1.9840122365951538
# Validation Loss:  340665.56048583984
# [epoch: 2, i:    99] avg mini-batch loss: 1.935186686515808
# [epoch: 2, i:   199] avg mini-batch loss: 2.0028652691841127
# [epoch: 2, i:   299] avg mini-batch loss: 1.9859934985637664
# [epoch: 2, i:   399] avg mini-batch loss: 1.931746187210083
# [epoch: 2, i:   499] avg mini-batch loss: 1.918774081468582
# [epoch: 2, i:   599] avg mini-batch loss: 1.9629041004180907
# [epoch: 2, i:   699] avg mini-batch loss: 1.983259516954422
# [epoch: 2, i:   799] avg mini-batch loss: 1.9399391269683839
# [epoch: 2, i:   899] avg mini-batch loss: 1.9840884351730346
# [epoch: 2, i:   999] avg mini-batch loss: 1.959777227640152
# [epoch: 2, i:  1099] avg mini-batch loss: 1.9824829769134522
# [epoch: 2, i:  1199] avg mini-batch loss: 1.9202221167087554
# [epoch: 2, i:  1299] avg mini-batch loss: 1.8874075973033906
# [epoch: 2, i:  1399] avg mini-batch loss: 1.9481074404716492
# [epoch: 2, i:  1499] avg mini-batch loss: 1.94555046916008
# [epoch: 2, i:  1599] avg mini-batch loss: 1.9469698178768158
# [epoch: 2, i:  1699] avg mini-batch loss: 1.8945965433120728
# [epoch: 2, i:  1799] avg mini-batch loss: 1.8993376302719116
# [epoch: 2, i:  1899] avg mini-batch loss: 1.916339762210846
# [epoch: 2, i:  1999] avg mini-batch loss: 1.9249123919010163
# [epoch: 2, i:  2099] avg mini-batch loss: 2.0144882237911226
# [epoch: 2, i:  2199] avg mini-batch loss: 1.9340733504295349
# [epoch: 2, i:  2299] avg mini-batch loss: 1.8420258277654649
# [epoch: 2, i:  2399] avg mini-batch loss: 1.9243097734451293
# [epoch: 2, i:  2499] avg mini-batch loss: 1.9875340688228607
# [epoch: 2, i:  2599] avg mini-batch loss: 1.8867994892597197
# [epoch: 2, i:  2699] avg mini-batch loss: 1.938591992855072
# [epoch: 2, i:  2799] avg mini-batch loss: 1.8895779585838317
# [epoch: 2, i:  2899] avg mini-batch loss: 1.9983496904373168
# [epoch: 2, i:  2999] avg mini-batch loss: 1.9650579404830932
# [epoch: 2, i:  3099] avg mini-batch loss: 1.9501201903820038
# [epoch: 2, i:  3199] avg mini-batch loss: 1.9666199147701264
# [epoch: 2, i:  3299] avg mini-batch loss: 1.9627949047088622
# [epoch: 2, i:  3399] avg mini-batch loss: 1.9590353494882584
# [epoch: 2, i:  3499] avg mini-batch loss: 1.9396631145477294
# [epoch: 2, i:  3599] avg mini-batch loss: 1.94693257689476
# [epoch: 2, i:  3699] avg mini-batch loss: 1.8978595292568208
# [epoch: 2, i:  3799] avg mini-batch loss: 1.8660195660591126
# [epoch: 2, i:  3899] avg mini-batch loss: 1.876952610015869
# [epoch: 2, i:  3999] avg mini-batch loss: 1.9316997802257538
# [epoch: 2, i:  4099] avg mini-batch loss: 1.9072186660766601
# [epoch: 2, i:  4199] avg mini-batch loss: 1.8607049691677093
# [epoch: 2, i:  4299] avg mini-batch loss: 1.8741921055316926
# [epoch: 2, i:  4399] avg mini-batch loss: 1.9041758358478547
# [epoch: 2, i:  4499] avg mini-batch loss: 1.8881790268421172
# [epoch: 2, i:  4599] avg mini-batch loss: 1.887331449985504
# [epoch: 2, i:  4699] avg mini-batch loss: 1.8855610466003419
# [epoch: 2, i:  4799] avg mini-batch loss: 1.938390976190567
# [epoch: 2, i:  4899] avg mini-batch loss: 1.8763156145811082
# [epoch: 2, i:  4999] avg mini-batch loss: 1.897772826552391
# [epoch: 2, i:  5099] avg mini-batch loss: 1.8858906614780426
# [epoch: 2, i:  5199] avg mini-batch loss: 1.9386748850345612
# [epoch: 2, i:  5299] avg mini-batch loss: 1.8976747125387192
# [epoch: 2, i:  5399] avg mini-batch loss: 1.929138857126236
# [epoch: 2, i:  5499] avg mini-batch loss: 1.9537513327598572
# [epoch: 2, i:  5599] avg mini-batch loss: 1.9956243741512298
# [epoch: 2, i:  5699] avg mini-batch loss: 1.8853547286987304
# [epoch: 2, i:  5799] avg mini-batch loss: 1.9649704122543334
# [epoch: 2, i:  5899] avg mini-batch loss: 1.9646392929553986
# [epoch: 2, i:  5999] avg mini-batch loss: 1.9114279127120972
# [epoch: 2, i:  6099] avg mini-batch loss: 1.8978118646144866
# [epoch: 2, i:  6199] avg mini-batch loss: 1.910864338874817
# [epoch: 2, i:  6299] avg mini-batch loss: 1.8900177907943725
# [epoch: 2, i:  6399] avg mini-batch loss: 1.8637137746810912
# [epoch: 2, i:  6499] avg mini-batch loss: 1.8774557477235794
# [epoch: 2, i:  6599] avg mini-batch loss: 1.9402371567487717
# [epoch: 2, i:  6699] avg mini-batch loss: 1.959098491668701
# [epoch: 2, i:  6799] avg mini-batch loss: 1.8935196340084075
# [epoch: 2, i:  6899] avg mini-batch loss: 1.9465518760681153
# [epoch: 2, i:  6999] avg mini-batch loss: 1.9241523087024688
# [epoch: 2, i:  7099] avg mini-batch loss: 1.88392773270607
# [epoch: 2, i:  7199] avg mini-batch loss: 1.972750883102417
# [epoch: 2, i:  7299] avg mini-batch loss: 1.8819040369987488
# [epoch: 2, i:  7399] avg mini-batch loss: 1.8970946514606475
# [epoch: 2, i:  7499] avg mini-batch loss: 1.952495082616806
# [epoch: 2, i:  7599] avg mini-batch loss: 1.9554847800731658
# [epoch: 2, i:  7699] avg mini-batch loss: 1.916662700176239
# [epoch: 2, i:  7799] avg mini-batch loss: 1.9279106628894807
# [epoch: 2, i:  7899] avg mini-batch loss: 1.8754687297344208
# [epoch: 2, i:  7999] avg mini-batch loss: 1.9305199378728866
# [epoch: 2, i:  8099] avg mini-batch loss: 1.938679437637329
# [epoch: 2, i:  8199] avg mini-batch loss: 1.86572531580925
# [epoch: 2, i:  8299] avg mini-batch loss: 1.90241841673851
# [epoch: 2, i:  8399] avg mini-batch loss: 1.8853246998786926
# [epoch: 2, i:  8499] avg mini-batch loss: 1.9211270964145661
# [epoch: 2, i:  8599] avg mini-batch loss: 1.8958426916599274
# [epoch: 2, i:  8699] avg mini-batch loss: 1.9005679607391357
# [epoch: 2, i:  8799] avg mini-batch loss: 1.9273175776004792
# [epoch: 2, i:  8899] avg mini-batch loss: 1.957783522605896
# [epoch: 2, i:  8999] avg mini-batch loss: 1.879177839756012
# [epoch: 2, i:  9099] avg mini-batch loss: 1.888340368270874
# [epoch: 2, i:  9199] avg mini-batch loss: 1.8792246913909911
# [epoch: 2, i:  9299] avg mini-batch loss: 1.8667861664295196
# [epoch: 2, i:  9399] avg mini-batch loss: 1.9500150930881501
# [epoch: 2, i:  9499] avg mini-batch loss: 1.8933513009548186
# [epoch: 2, i:  9599] avg mini-batch loss: 1.822403569817543
# [epoch: 2, i:  9699] avg mini-batch loss: 1.8825230920314788
# [epoch: 2, i:  9799] avg mini-batch loss: 1.908007754087448
# [epoch: 2, i:  9899] avg mini-batch loss: 1.8324257922172547
# [epoch: 2, i:  9999] avg mini-batch loss: 1.8774294173717498
# Validation Loss:  120879.01547861099
# [epoch: 3, i:    99] avg mini-batch loss: 1.9299532562494277
# [epoch: 3, i:   199] avg mini-batch loss: 1.915340085029602
# [epoch: 3, i:   299] avg mini-batch loss: 1.8912558495998382
# [epoch: 3, i:   399] avg mini-batch loss: 1.876561588048935
# [epoch: 3, i:   499] avg mini-batch loss: 1.9225598406791686
# [epoch: 3, i:   599] avg mini-batch loss: 2.027211627960205
# [epoch: 3, i:   699] avg mini-batch loss: 1.86263434946537
# [epoch: 3, i:   799] avg mini-batch loss: 1.9993593096733093
# [epoch: 3, i:   899] avg mini-batch loss: 1.9082972288131714
# [epoch: 3, i:   999] avg mini-batch loss: 1.9102412164211273
# [epoch: 3, i:  1099] avg mini-batch loss: 1.9272000563144684
# [epoch: 3, i:  1199] avg mini-batch loss: 1.8609106874465942
# [epoch: 3, i:  1299] avg mini-batch loss: 1.919339839220047
# [epoch: 3, i:  1399] avg mini-batch loss: 1.9278333342075349
# [epoch: 3, i:  1499] avg mini-batch loss: 1.9067788064479827
# [epoch: 3, i:  1599] avg mini-batch loss: 1.928319609761238
# [epoch: 3, i:  1699] avg mini-batch loss: 1.8718735802173614
# [epoch: 3, i:  1799] avg mini-batch loss: 1.8949257349967956
# [epoch: 3, i:  1899] avg mini-batch loss: 1.8449667799472809
# [epoch: 3, i:  1999] avg mini-batch loss: 1.900032389163971
# [epoch: 3, i:  2099] avg mini-batch loss: 1.8679214257001877
# [epoch: 3, i:  2199] avg mini-batch loss: 1.9391023486852645
# [epoch: 3, i:  2299] avg mini-batch loss: 1.9083480083942412
# [epoch: 3, i:  2399] avg mini-batch loss: 1.8653906571865082
# [epoch: 3, i:  2499] avg mini-batch loss: 1.8208174014091492
# [epoch: 3, i:  2599] avg mini-batch loss: 1.915546374320984
# [epoch: 3, i:  2699] avg mini-batch loss: 1.9391914081573487
# [epoch: 3, i:  2799] avg mini-batch loss: 1.932068670988083
# [epoch: 3, i:  2899] avg mini-batch loss: 1.8885059356689453
# [epoch: 3, i:  2999] avg mini-batch loss: 1.9519905960559845
# [epoch: 3, i:  3099] avg mini-batch loss: 1.8338263517618179
# [epoch: 3, i:  3199] avg mini-batch loss: 1.9416502106189728
# [epoch: 3, i:  3299] avg mini-batch loss: 1.9646049165725707
# [epoch: 3, i:  3399] avg mini-batch loss: 1.8415486240386962
# [epoch: 3, i:  3499] avg mini-batch loss: 1.8435095113515854
# [epoch: 3, i:  3599] avg mini-batch loss: 1.937345563173294
# [epoch: 3, i:  3699] avg mini-batch loss: 1.9274379444122314
# [epoch: 3, i:  3799] avg mini-batch loss: 1.968920863866806
# [epoch: 3, i:  3899] avg mini-batch loss: 1.8757640099525452
# [epoch: 3, i:  3999] avg mini-batch loss: 1.9298623311519623
# [epoch: 3, i:  4099] avg mini-batch loss: 1.8526084077358247
# [epoch: 3, i:  4199] avg mini-batch loss: 1.8333491307497025
# [epoch: 3, i:  4299] avg mini-batch loss: 1.869517096877098
# [epoch: 3, i:  4399] avg mini-batch loss: 1.844240226149559
# [epoch: 3, i:  4499] avg mini-batch loss: 1.9191980636119843
# [epoch: 3, i:  4599] avg mini-batch loss: 1.980793570280075
# [epoch: 3, i:  4699] avg mini-batch loss: 1.8255402529239655
# [epoch: 3, i:  4799] avg mini-batch loss: 1.8178334403038026
# [epoch: 3, i:  4899] avg mini-batch loss: 1.887627034187317
# [epoch: 3, i:  4999] avg mini-batch loss: 1.8713677054643632
# [epoch: 3, i:  5099] avg mini-batch loss: 1.8680037987232208
# [epoch: 3, i:  5199] avg mini-batch loss: 1.9131625807285308
# [epoch: 3, i:  5299] avg mini-batch loss: 1.893939419388771
# [epoch: 3, i:  5399] avg mini-batch loss: 1.9530565655231475
# [epoch: 3, i:  5499] avg mini-batch loss: 1.8352401435375214
# [epoch: 3, i:  5599] avg mini-batch loss: 1.9031478941440583
# [epoch: 3, i:  5699] avg mini-batch loss: 2.0474377131462096
# [epoch: 3, i:  5799] avg mini-batch loss: 1.9379202723503113
# [epoch: 3, i:  5899] avg mini-batch loss: 1.920780439376831
# [epoch: 3, i:  5999] avg mini-batch loss: 1.8512526881694793
# [epoch: 3, i:  6099] avg mini-batch loss: 1.8988367736339569
# [epoch: 3, i:  6199] avg mini-batch loss: 1.8892101049423218
# [epoch: 3, i:  6299] avg mini-batch loss: 1.9256768327951432
# [epoch: 3, i:  6399] avg mini-batch loss: 1.9391401094198226
# [epoch: 3, i:  6499] avg mini-batch loss: 1.9586850059032441
# [epoch: 3, i:  6599] avg mini-batch loss: 1.829320193529129
# [epoch: 3, i:  6699] avg mini-batch loss: 1.8275168031454085
# [epoch: 3, i:  6799] avg mini-batch loss: 1.8945820784568788
# [epoch: 3, i:  6899] avg mini-batch loss: 1.9229132759571075
# [epoch: 3, i:  6999] avg mini-batch loss: 1.8793971920013428
# [epoch: 3, i:  7099] avg mini-batch loss: 1.8336290848255157
# [epoch: 3, i:  7199] avg mini-batch loss: 1.9457496809959411
# [epoch: 3, i:  7299] avg mini-batch loss: 1.9089915192127227
# [epoch: 3, i:  7399] avg mini-batch loss: 1.8818684482574464
# [epoch: 3, i:  7499] avg mini-batch loss: 1.8663552796840668
# [epoch: 3, i:  7599] avg mini-batch loss: 1.9555745458602904
# [epoch: 3, i:  7699] avg mini-batch loss: 1.8833624696731568
# [epoch: 3, i:  7799] avg mini-batch loss: 1.9275688278675078
# [epoch: 3, i:  7899] avg mini-batch loss: 1.8370429480075836
# [epoch: 3, i:  7999] avg mini-batch loss: 1.9496291387081146
# [epoch: 3, i:  8099] avg mini-batch loss: 1.91261207818985
# [epoch: 3, i:  8199] avg mini-batch loss: 1.8347466135025023
# [epoch: 3, i:  8299] avg mini-batch loss: 1.8299498867988586
# [epoch: 3, i:  8399] avg mini-batch loss: 1.9089287495613099
# [epoch: 3, i:  8499] avg mini-batch loss: 1.9175256407260894
# [epoch: 3, i:  8599] avg mini-batch loss: 1.8086033576726914
# [epoch: 3, i:  8699] avg mini-batch loss: 1.83405233502388
# [epoch: 3, i:  8799] avg mini-batch loss: 1.884334438443184
# [epoch: 3, i:  8899] avg mini-batch loss: 1.8381563603878022
# [epoch: 3, i:  8999] avg mini-batch loss: 1.8527683305740357
# [epoch: 3, i:  9099] avg mini-batch loss: 1.936295450925827
# [epoch: 3, i:  9199] avg mini-batch loss: 1.8072785729169845
# [epoch: 3, i:  9299] avg mini-batch loss: 1.9281500005722045
# [epoch: 3, i:  9399] avg mini-batch loss: 1.9097565531730651
# [epoch: 3, i:  9499] avg mini-batch loss: 1.8183962136507035
# [epoch: 3, i:  9599] avg mini-batch loss: 1.8594128346443177
# [epoch: 3, i:  9699] avg mini-batch loss: 1.850995610356331
# [epoch: 3, i:  9799] avg mini-batch loss: 1.810448615550995
# [epoch: 3, i:  9899] avg mini-batch loss: 1.8704494202136994
# [epoch: 3, i:  9999] avg mini-batch loss: 1.768651316165924
# Validation Loss:  62272.98588132858
# [epoch: 4, i:    99] avg mini-batch loss: 1.8597319144010545
# [epoch: 4, i:   199] avg mini-batch loss: 1.7890487492084504
# [epoch: 4, i:   299] avg mini-batch loss: 1.858375559449196
# [epoch: 4, i:   399] avg mini-batch loss: 1.8478894573450089
# [epoch: 4, i:   499] avg mini-batch loss: 1.8706720185279846
# [epoch: 4, i:   599] avg mini-batch loss: 1.8830161666870118
# [epoch: 4, i:   699] avg mini-batch loss: 1.8481838202476502
# [epoch: 4, i:   799] avg mini-batch loss: 1.9035859787464142
# [epoch: 4, i:   899] avg mini-batch loss: 1.7881879884004592
# [epoch: 4, i:   999] avg mini-batch loss: 1.8128004330396652
# [epoch: 4, i:  1099] avg mini-batch loss: 1.9267613446712495
# [epoch: 4, i:  1199] avg mini-batch loss: 1.9209721505641937
# [epoch: 4, i:  1299] avg mini-batch loss: 1.8987603974342346
# [epoch: 4, i:  1399] avg mini-batch loss: 1.8038316565752028
# [epoch: 4, i:  1499] avg mini-batch loss: 1.8666009956598282
# [epoch: 4, i:  1599] avg mini-batch loss: 1.8396432489156722
# [epoch: 4, i:  1699] avg mini-batch loss: 1.904317564368248
# [epoch: 4, i:  1799] avg mini-batch loss: 1.9036795538663864
# [epoch: 4, i:  1899] avg mini-batch loss: 1.863426696062088
# [epoch: 4, i:  1999] avg mini-batch loss: 1.827530779838562
# [epoch: 4, i:  2099] avg mini-batch loss: 1.859598447084427
# [epoch: 4, i:  2199] avg mini-batch loss: 1.8856971400976181
# [epoch: 4, i:  2299] avg mini-batch loss: 1.861561862230301
# [epoch: 4, i:  2399] avg mini-batch loss: 1.8475471246242523
# [epoch: 4, i:  2499] avg mini-batch loss: 1.8310217618942262
# [epoch: 4, i:  2599] avg mini-batch loss: 1.8415632116794587
# [epoch: 4, i:  2699] avg mini-batch loss: 1.8488943767547608
# [epoch: 4, i:  2799] avg mini-batch loss: 1.9085058414936065
# [epoch: 4, i:  2899] avg mini-batch loss: 1.8917923218011856
# [epoch: 4, i:  2999] avg mini-batch loss: 1.826514402627945
# [epoch: 4, i:  3099] avg mini-batch loss: 1.8565485906600951
# [epoch: 4, i:  3199] avg mini-batch loss: 1.9139892625808717
# [epoch: 4, i:  3299] avg mini-batch loss: 1.8132947391271592
# [epoch: 4, i:  3399] avg mini-batch loss: 1.8432470321655274
# [epoch: 4, i:  3499] avg mini-batch loss: 1.8648001897335051
# [epoch: 4, i:  3599] avg mini-batch loss: 1.832731339931488
# [epoch: 4, i:  3699] avg mini-batch loss: 1.8688303077220916
# [epoch: 4, i:  3799] avg mini-batch loss: 1.9095457899570465
# [epoch: 4, i:  3899] avg mini-batch loss: 1.850616147518158
# [epoch: 4, i:  3999] avg mini-batch loss: 1.9142556917667388
# [epoch: 4, i:  4099] avg mini-batch loss: 1.846381601691246
# [epoch: 4, i:  4199] avg mini-batch loss: 1.8055757480859755
# [epoch: 4, i:  4299] avg mini-batch loss: 1.772968327999115
# [epoch: 4, i:  4399] avg mini-batch loss: 1.9249046707153321
# [epoch: 4, i:  4499] avg mini-batch loss: 1.7922456669807434
# [epoch: 4, i:  4599] avg mini-batch loss: 1.8369350111484528
# [epoch: 4, i:  4699] avg mini-batch loss: 1.8829142904281617
# [epoch: 4, i:  4799] avg mini-batch loss: 1.8198474991321563
# [epoch: 4, i:  4899] avg mini-batch loss: 1.8786569905281068
# [epoch: 4, i:  4999] avg mini-batch loss: 1.8389258372783661
# [epoch: 4, i:  5099] avg mini-batch loss: 1.711943734884262
# [epoch: 4, i:  5199] avg mini-batch loss: 1.8852796149253845
# [epoch: 4, i:  5299] avg mini-batch loss: 1.838393791913986
# [epoch: 4, i:  5399] avg mini-batch loss: 1.8940947377681732
# [epoch: 4, i:  5499] avg mini-batch loss: 1.8173584884405136
# [epoch: 4, i:  5599] avg mini-batch loss: 1.7811445194482802
# [epoch: 4, i:  5699] avg mini-batch loss: 1.8707850313186645
# [epoch: 4, i:  5799] avg mini-batch loss: 1.8909860503673555
# [epoch: 4, i:  5899] avg mini-batch loss: 1.8811848747730255
# [epoch: 4, i:  5999] avg mini-batch loss: 1.7754186183214187
# [epoch: 4, i:  6099] avg mini-batch loss: 1.7641562134027482
# [epoch: 4, i:  6199] avg mini-batch loss: 1.813580151796341
# [epoch: 4, i:  6299] avg mini-batch loss: 1.824995197057724
# [epoch: 4, i:  6399] avg mini-batch loss: 1.9157266771793366
# [epoch: 4, i:  6499] avg mini-batch loss: 1.8750628566741943
# [epoch: 4, i:  6599] avg mini-batch loss: 1.7330694037675858
# [epoch: 4, i:  6699] avg mini-batch loss: 1.7725766962766647
# [epoch: 4, i:  6799] avg mini-batch loss: 1.8068264943361283
# [epoch: 4, i:  6899] avg mini-batch loss: 1.8230136907100678
# [epoch: 4, i:  6999] avg mini-batch loss: 1.8362150913476945
# [epoch: 4, i:  7099] avg mini-batch loss: 1.8588451004028321
# [epoch: 4, i:  7199] avg mini-batch loss: 1.8615868508815765
# [epoch: 4, i:  7299] avg mini-batch loss: 1.839644696712494
# [epoch: 4, i:  7399] avg mini-batch loss: 1.7779810172319412
# [epoch: 4, i:  7499] avg mini-batch loss: 1.7633816885948181
# [epoch: 4, i:  7599] avg mini-batch loss: 1.8269210541248322
# [epoch: 4, i:  7699] avg mini-batch loss: 1.7770796966552735
# [epoch: 4, i:  7799] avg mini-batch loss: 1.8608230197429656
# [epoch: 4, i:  7899] avg mini-batch loss: 1.873290292620659
# [epoch: 4, i:  7999] avg mini-batch loss: 1.7769658434391022
# [epoch: 4, i:  8099] avg mini-batch loss: 1.789698132276535
# [epoch: 4, i:  8199] avg mini-batch loss: 1.7570450019836426
# [epoch: 4, i:  8299] avg mini-batch loss: 1.8288242602348328
# [epoch: 4, i:  8399] avg mini-batch loss: 1.837873637676239
# [epoch: 4, i:  8499] avg mini-batch loss: 1.8364608120918273
# [epoch: 4, i:  8599] avg mini-batch loss: 1.7467354506254196
# [epoch: 4, i:  8699] avg mini-batch loss: 1.8089077299833298
# [epoch: 4, i:  8799] avg mini-batch loss: 1.8012561893463135
# [epoch: 4, i:  8899] avg mini-batch loss: 1.8466758298873902
# [epoch: 4, i:  8999] avg mini-batch loss: 1.8418419873714447
# [epoch: 4, i:  9099] avg mini-batch loss: 1.9018692296743394
# [epoch: 4, i:  9199] avg mini-batch loss: 1.8135528463125228
# [epoch: 4, i:  9299] avg mini-batch loss: 1.8696391052007675
# [epoch: 4, i:  9399] avg mini-batch loss: 1.8326033008098603
# [epoch: 4, i:  9499] avg mini-batch loss: 1.8046549212932588
# [epoch: 4, i:  9599] avg mini-batch loss: 1.8250208526849747
# [epoch: 4, i:  9699] avg mini-batch loss: 1.8360031390190124
# [epoch: 4, i:  9799] avg mini-batch loss: 1.8568016344308853
# [epoch: 4, i:  9899] avg mini-batch loss: 1.815285831093788
# [epoch: 4, i:  9999] avg mini-batch loss: 1.7505134952068329
# Validation Loss:  21175.02158564329
# [epoch: 5, i:    99] avg mini-batch loss: 1.8131565088033677
# [epoch: 5, i:   199] avg mini-batch loss: 1.8210018610954284
# [epoch: 5, i:   299] avg mini-batch loss: 1.8095192646980285
# [epoch: 5, i:   399] avg mini-batch loss: 1.810515570640564
# [epoch: 5, i:   499] avg mini-batch loss: 1.7968136954307556
# [epoch: 5, i:   599] avg mini-batch loss: 1.7644642055034638
# [epoch: 5, i:   699] avg mini-batch loss: 1.8658197861909867
# [epoch: 5, i:   799] avg mini-batch loss: 1.7950485688447952
# [epoch: 5, i:   899] avg mini-batch loss: 1.774327484369278
# [epoch: 5, i:   999] avg mini-batch loss: 1.7559768486022949
# [epoch: 5, i:  1099] avg mini-batch loss: 1.7960222804546355
# [epoch: 5, i:  1199] avg mini-batch loss: 1.8348264068365097
# [epoch: 5, i:  1299] avg mini-batch loss: 1.816291230916977
# [epoch: 5, i:  1399] avg mini-batch loss: 1.808282231092453
# [epoch: 5, i:  1499] avg mini-batch loss: 1.7763643342256545
# [epoch: 5, i:  1599] avg mini-batch loss: 1.8837791323661803
# [epoch: 5, i:  1699] avg mini-batch loss: 1.805413083434105
# [epoch: 5, i:  1799] avg mini-batch loss: 1.7829142534732818
# [epoch: 5, i:  1899] avg mini-batch loss: 1.7400806444883345
# [epoch: 5, i:  1999] avg mini-batch loss: 1.837807285785675
# [epoch: 5, i:  2099] avg mini-batch loss: 1.8371014177799225
# [epoch: 5, i:  2199] avg mini-batch loss: 1.780660970211029
# [epoch: 5, i:  2299] avg mini-batch loss: 1.756508367061615
# [epoch: 5, i:  2399] avg mini-batch loss: 1.7192778307199479
# [epoch: 5, i:  2499] avg mini-batch loss: 1.8956620180606842
# [epoch: 5, i:  2599] avg mini-batch loss: 1.7616372668743134
# [epoch: 5, i:  2699] avg mini-batch loss: 1.8781367236375808
# [epoch: 5, i:  2799] avg mini-batch loss: 1.780817188024521
# [epoch: 5, i:  2899] avg mini-batch loss: 1.7964257210493089
# [epoch: 5, i:  2999] avg mini-batch loss: 1.7793658059835433
# [epoch: 5, i:  3099] avg mini-batch loss: 1.7316130423545837
# [epoch: 5, i:  3199] avg mini-batch loss: 1.8433704382181169
# [epoch: 5, i:  3299] avg mini-batch loss: 1.8050097131729126
# [epoch: 5, i:  3399] avg mini-batch loss: 1.795852934718132
# [epoch: 5, i:  3499] avg mini-batch loss: 1.7678391969203948
# [epoch: 5, i:  3599] avg mini-batch loss: 1.8762203055620192
# [epoch: 5, i:  3699] avg mini-batch loss: 1.822675393819809
# [epoch: 5, i:  3799] avg mini-batch loss: 1.8789661383628846
# [epoch: 5, i:  3899] avg mini-batch loss: 1.723374868631363
# [epoch: 5, i:  3999] avg mini-batch loss: 1.7257747238874435
# [epoch: 5, i:  4099] avg mini-batch loss: 1.76051826775074
# [epoch: 5, i:  4199] avg mini-batch loss: 1.7144238007068635
# [epoch: 5, i:  4299] avg mini-batch loss: 1.8296573585271836
# [epoch: 5, i:  4399] avg mini-batch loss: 1.7990903013944626
# [epoch: 5, i:  4499] avg mini-batch loss: 1.7116487061977386
# [epoch: 5, i:  4599] avg mini-batch loss: 1.8236543697118759
# [epoch: 5, i:  4699] avg mini-batch loss: 1.808383709192276
# [epoch: 5, i:  4799] avg mini-batch loss: 1.8569017899036409
# [epoch: 5, i:  4899] avg mini-batch loss: 1.7225150382518768
# [epoch: 5, i:  4999] avg mini-batch loss: 1.8065206623077392
# [epoch: 5, i:  5099] avg mini-batch loss: 1.8145634198188783
# [epoch: 5, i:  5199] avg mini-batch loss: 1.7626064282655716
# [epoch: 5, i:  5299] avg mini-batch loss: 1.7990978932380677
# [epoch: 5, i:  5399] avg mini-batch loss: 1.7536492359638214
# [epoch: 5, i:  5499] avg mini-batch loss: 1.7622811371088027
# [epoch: 5, i:  5599] avg mini-batch loss: 1.7335904550552368
# [epoch: 5, i:  5699] avg mini-batch loss: 1.7672708660364151
# [epoch: 5, i:  5799] avg mini-batch loss: 1.7996703892946244
# [epoch: 5, i:  5899] avg mini-batch loss: 1.7604240089654923
# [epoch: 5, i:  5999] avg mini-batch loss: 1.8153121316432952
# [epoch: 5, i:  6099] avg mini-batch loss: 1.7854654204845428
# [epoch: 5, i:  6199] avg mini-batch loss: 1.729857617020607
# [epoch: 5, i:  6299] avg mini-batch loss: 1.7714614629745484
# [epoch: 5, i:  6399] avg mini-batch loss: 1.8425846034288407
# [epoch: 5, i:  6499] avg mini-batch loss: 1.7450392425060273
# [epoch: 5, i:  6599] avg mini-batch loss: 1.8115404546260834
# [epoch: 5, i:  6699] avg mini-batch loss: 1.7666702377796173
# [epoch: 5, i:  6799] avg mini-batch loss: 1.7028555929660798
# [epoch: 5, i:  6899] avg mini-batch loss: 1.807555587887764
# [epoch: 5, i:  6999] avg mini-batch loss: 1.7180500292778016
# [epoch: 5, i:  7099] avg mini-batch loss: 1.7355981689691544
# [epoch: 5, i:  7199] avg mini-batch loss: 1.717920159101486
# [epoch: 5, i:  7299] avg mini-batch loss: 1.6454614233970641
# [epoch: 5, i:  7399] avg mini-batch loss: 1.6866272115707397
# [epoch: 5, i:  7499] avg mini-batch loss: 1.7794446796178818
# [epoch: 5, i:  7599] avg mini-batch loss: 1.8041522598266602
# [epoch: 5, i:  7699] avg mini-batch loss: 1.8584891110658646
# [epoch: 5, i:  7799] avg mini-batch loss: 1.8199474799633026
# [epoch: 5, i:  7899] avg mini-batch loss: 1.780305295586586
# [epoch: 5, i:  7999] avg mini-batch loss: 1.747916032075882
# [epoch: 5, i:  8099] avg mini-batch loss: 1.76525259912014
# [epoch: 5, i:  8199] avg mini-batch loss: 1.761463878750801
# [epoch: 5, i:  8299] avg mini-batch loss: 1.7544287210702896
# [epoch: 5, i:  8399] avg mini-batch loss: 1.7268927091360091
# [epoch: 5, i:  8499] avg mini-batch loss: 1.7856378495693206
# [epoch: 5, i:  8599] avg mini-batch loss: 1.7872684109210968
# [epoch: 5, i:  8699] avg mini-batch loss: 1.7340685445070267
# [epoch: 5, i:  8799] avg mini-batch loss: 1.7867082345485688
# [epoch: 5, i:  8899] avg mini-batch loss: 1.7888682782649994
# [epoch: 5, i:  8999] avg mini-batch loss: 1.6517670160531999
# [epoch: 5, i:  9099] avg mini-batch loss: 1.7353505861759186
# [epoch: 5, i:  9199] avg mini-batch loss: 1.751467261314392
# [epoch: 5, i:  9299] avg mini-batch loss: 1.8386780679225923
# [epoch: 5, i:  9399] avg mini-batch loss: 1.8146451479196548
# [epoch: 5, i:  9499] avg mini-batch loss: 1.7907806193828584
# [epoch: 5, i:  9599] avg mini-batch loss: 1.7380296379327773
# [epoch: 5, i:  9699] avg mini-batch loss: 1.724985612630844
# [epoch: 5, i:  9799] avg mini-batch loss: 1.8402846884727477
# [epoch: 5, i:  9899] avg mini-batch loss: 1.7389260137081146
# [epoch: 5, i:  9999] avg mini-batch loss: 1.78813669860363
# Validation Loss:  37515.139561891556
# [epoch: 6, i:    99] avg mini-batch loss: 1.6888871747255325
# [epoch: 6, i:   199] avg mini-batch loss: 1.7406145966053008
# [epoch: 6, i:   299] avg mini-batch loss: 1.7569231420755387
# [epoch: 6, i:   399] avg mini-batch loss: 1.8519268721342086
# [epoch: 6, i:   499] avg mini-batch loss: 1.8769396460056305
# [epoch: 6, i:   599] avg mini-batch loss: 1.7683897072076797
# [epoch: 6, i:   699] avg mini-batch loss: 1.7219706642627717
# [epoch: 6, i:   799] avg mini-batch loss: 1.8455807727575302
# [epoch: 6, i:   899] avg mini-batch loss: 1.758719391822815
# [epoch: 6, i:   999] avg mini-batch loss: 1.729721575975418
# [epoch: 6, i:  1099] avg mini-batch loss: 1.881575453877449
# [epoch: 6, i:  1199] avg mini-batch loss: 1.6836727648973464
# [epoch: 6, i:  1299] avg mini-batch loss: 1.7293138590455055
# [epoch: 6, i:  1399] avg mini-batch loss: 1.8435326033830643
# [epoch: 6, i:  1499] avg mini-batch loss: 1.7121112412214279
# [epoch: 6, i:  1599] avg mini-batch loss: 1.7129487735033035
# [epoch: 6, i:  1699] avg mini-batch loss: 1.7056659734249116
# [epoch: 6, i:  1799] avg mini-batch loss: 1.7742155623435973
# [epoch: 6, i:  1899] avg mini-batch loss: 1.7931702595949173
# [epoch: 6, i:  1999] avg mini-batch loss: 1.804250287413597
# [epoch: 6, i:  2099] avg mini-batch loss: 1.7469405111670495
# [epoch: 6, i:  2199] avg mini-batch loss: 1.746103950738907
# [epoch: 6, i:  2299] avg mini-batch loss: 1.7122206062078476
# [epoch: 6, i:  2399] avg mini-batch loss: 1.7452818602323532
# [epoch: 6, i:  2499] avg mini-batch loss: 1.812399104833603
# [epoch: 6, i:  2599] avg mini-batch loss: 1.801563676595688
# [epoch: 6, i:  2699] avg mini-batch loss: 1.6967786747217177
# [epoch: 6, i:  2799] avg mini-batch loss: 1.7010932683944702
# [epoch: 6, i:  2899] avg mini-batch loss: 1.7550177705287933
# [epoch: 6, i:  2999] avg mini-batch loss: 1.7155086269974709
# [epoch: 6, i:  3099] avg mini-batch loss: 1.8332840156555177
# [epoch: 6, i:  3199] avg mini-batch loss: 1.7157806420326234
# [epoch: 6, i:  3299] avg mini-batch loss: 1.7584798586368562
# [epoch: 6, i:  3399] avg mini-batch loss: 1.713081620335579
# [epoch: 6, i:  3499] avg mini-batch loss: 1.7485326033830644
# [epoch: 6, i:  3599] avg mini-batch loss: 1.8455031192302704
# [epoch: 6, i:  3699] avg mini-batch loss: 1.7552804356813432
# [epoch: 6, i:  3799] avg mini-batch loss: 1.7302699148654939
# [epoch: 6, i:  3899] avg mini-batch loss: 1.7859122228622437
# [epoch: 6, i:  3999] avg mini-batch loss: 1.769846717119217
# [epoch: 6, i:  4099] avg mini-batch loss: 1.6721384888887405
# [epoch: 6, i:  4199] avg mini-batch loss: 1.7707638615369796
# [epoch: 6, i:  4299] avg mini-batch loss: 1.7578146994113921
# [epoch: 6, i:  4399] avg mini-batch loss: 1.7056112802028656
# [epoch: 6, i:  4499] avg mini-batch loss: 1.7564204972982407
# [epoch: 6, i:  4599] avg mini-batch loss: 1.70913392663002
# [epoch: 6, i:  4699] avg mini-batch loss: 1.694093138575554
# [epoch: 6, i:  4799] avg mini-batch loss: 1.7737667232751846
# [epoch: 6, i:  4899] avg mini-batch loss: 1.7997606283426284
# [epoch: 6, i:  4999] avg mini-batch loss: 1.7351474142074585
# [epoch: 6, i:  5099] avg mini-batch loss: 1.6943731588125228
# [epoch: 6, i:  5199] avg mini-batch loss: 1.747400832772255
# [epoch: 6, i:  5299] avg mini-batch loss: 1.7376237601041793
# [epoch: 6, i:  5399] avg mini-batch loss: 1.6908289700746537
# [epoch: 6, i:  5499] avg mini-batch loss: 1.7189713382720948
# [epoch: 6, i:  5599] avg mini-batch loss: 1.7286187982559205
# [epoch: 6, i:  5699] avg mini-batch loss: 1.7368387460708619
# [epoch: 6, i:  5799] avg mini-batch loss: 1.778362081050873
# [epoch: 6, i:  5899] avg mini-batch loss: 1.6568047934770584
# [epoch: 6, i:  5999] avg mini-batch loss: 1.7395325458049775
# [epoch: 6, i:  6099] avg mini-batch loss: 1.8865073853731156
# [epoch: 6, i:  6199] avg mini-batch loss: 1.7168208074569702
# [epoch: 6, i:  6299] avg mini-batch loss: 1.7640049809217453
# [epoch: 6, i:  6399] avg mini-batch loss: 1.770799186229706
# [epoch: 6, i:  6499] avg mini-batch loss: 1.6941563504934312
# [epoch: 6, i:  6599] avg mini-batch loss: 1.5882398664951325
# [epoch: 6, i:  6699] avg mini-batch loss: 1.7993778747320175
# [epoch: 6, i:  6799] avg mini-batch loss: 1.6878787523508072
# [epoch: 6, i:  6899] avg mini-batch loss: 1.730041144490242
# [epoch: 6, i:  6999] avg mini-batch loss: 1.7061271184682847
# [epoch: 6, i:  7099] avg mini-batch loss: 1.7039806243777276
# [epoch: 6, i:  7199] avg mini-batch loss: 1.7501732623577118
# [epoch: 6, i:  7299] avg mini-batch loss: 1.6856777745485305
# [epoch: 6, i:  7399] avg mini-batch loss: 1.7729751747846603
# [epoch: 6, i:  7499] avg mini-batch loss: 1.7335146260261536
# [epoch: 6, i:  7599] avg mini-batch loss: 1.6690981251001358
# [epoch: 6, i:  7699] avg mini-batch loss: 1.6757073003053664
# [epoch: 6, i:  7799] avg mini-batch loss: 1.6528329467773437
# [epoch: 6, i:  7899] avg mini-batch loss: 1.7764326071739196
# [epoch: 6, i:  7999] avg mini-batch loss: 1.6689219772815704
# [epoch: 6, i:  8099] avg mini-batch loss: 1.7496413612365722
# [epoch: 6, i:  8199] avg mini-batch loss: 1.6835854810476303
# [epoch: 6, i:  8299] avg mini-batch loss: 1.714650229215622
# [epoch: 6, i:  8399] avg mini-batch loss: 1.7177066731452941
# [epoch: 6, i:  8499] avg mini-batch loss: 1.684254240989685
# [epoch: 6, i:  8599] avg mini-batch loss: 1.8588399934768676
# [epoch: 6, i:  8699] avg mini-batch loss: 1.7422994893789292
# [epoch: 6, i:  8799] avg mini-batch loss: 1.7037939566373825
# [epoch: 6, i:  8899] avg mini-batch loss: 1.6477845650911331
# [epoch: 6, i:  8999] avg mini-batch loss: 1.6771465438604354
# [epoch: 6, i:  9099] avg mini-batch loss: 1.6957274943590164
# [epoch: 6, i:  9199] avg mini-batch loss: 1.7867003262043
# [epoch: 6, i:  9299] avg mini-batch loss: 1.7806148612499237
# [epoch: 6, i:  9399] avg mini-batch loss: 1.6463909757137298
# [epoch: 6, i:  9499] avg mini-batch loss: 1.6489731669425964
# [epoch: 6, i:  9599] avg mini-batch loss: 1.8208864521980286
# [epoch: 6, i:  9699] avg mini-batch loss: 1.6768206238746644
# [epoch: 6, i:  9799] avg mini-batch loss: 1.6475312274694442
# [epoch: 6, i:  9899] avg mini-batch loss: 1.6735317122936249
# [epoch: 6, i:  9999] avg mini-batch loss: 1.748455114364624
# Validation Loss:  38997.967865976505
# [epoch: 7, i:    99] avg mini-batch loss: 1.6802567619085311
# [epoch: 7, i:   199] avg mini-batch loss: 1.6484991699457168
# [epoch: 7, i:   299] avg mini-batch loss: 1.65116563975811
# [epoch: 7, i:   399] avg mini-batch loss: 1.6944993513822555
# [epoch: 7, i:   499] avg mini-batch loss: 1.7803899985551834
# [epoch: 7, i:   599] avg mini-batch loss: 1.6151392042636872
# [epoch: 7, i:   699] avg mini-batch loss: 1.7045391070842744
# [epoch: 7, i:   799] avg mini-batch loss: 1.6756385177373887
# [epoch: 7, i:   899] avg mini-batch loss: 1.7710580325126648
# [epoch: 7, i:   999] avg mini-batch loss: 1.6660026639699936
# [epoch: 7, i:  1099] avg mini-batch loss: 1.7345642042160034
# [epoch: 7, i:  1199] avg mini-batch loss: 1.8493448680639266
# [epoch: 7, i:  1299] avg mini-batch loss: 1.8348905658721923
# [epoch: 7, i:  1399] avg mini-batch loss: 1.725594848394394
# [epoch: 7, i:  1499] avg mini-batch loss: 1.680595387816429
# [epoch: 7, i:  1599] avg mini-batch loss: 1.6674519258737563
# [epoch: 7, i:  1699] avg mini-batch loss: 1.7003424006700516
# [epoch: 7, i:  1799] avg mini-batch loss: 1.7720299637317658
# [epoch: 7, i:  1899] avg mini-batch loss: 1.6939802104234696
# [epoch: 7, i:  1999] avg mini-batch loss: 1.6934641522169114
# [epoch: 7, i:  2099] avg mini-batch loss: 1.639597772359848
# [epoch: 7, i:  2199] avg mini-batch loss: 1.722114748954773
# [epoch: 7, i:  2299] avg mini-batch loss: 1.6533770370483398
# [epoch: 7, i:  2399] avg mini-batch loss: 1.7108085054159163
# [epoch: 7, i:  2499] avg mini-batch loss: 1.7122983837127685
# [epoch: 7, i:  2599] avg mini-batch loss: 1.691940694451332
# [epoch: 7, i:  2699] avg mini-batch loss: 1.74469486951828
# [epoch: 7, i:  2799] avg mini-batch loss: 1.7881045961380004
# [epoch: 7, i:  2899] avg mini-batch loss: 1.7378724116086959
# [epoch: 7, i:  2999] avg mini-batch loss: 1.6136780655384064
# [epoch: 7, i:  3099] avg mini-batch loss: 1.7723724472522735
# [epoch: 7, i:  3199] avg mini-batch loss: 1.6691376465559005
# [epoch: 7, i:  3299] avg mini-batch loss: 1.7119882464408875
# [epoch: 7, i:  3399] avg mini-batch loss: 1.6376802372932433
# [epoch: 7, i:  3499] avg mini-batch loss: 1.5766951584815978
# [epoch: 7, i:  3599] avg mini-batch loss: 1.7232813268899918
# [epoch: 7, i:  3699] avg mini-batch loss: 1.7070368719100952
# [epoch: 7, i:  3799] avg mini-batch loss: 1.640289153456688
# [epoch: 7, i:  3899] avg mini-batch loss: 1.6965270411968232
# [epoch: 7, i:  3999] avg mini-batch loss: 1.6537829399108888
# [epoch: 7, i:  4099] avg mini-batch loss: 1.6758501625061035
# [epoch: 7, i:  4199] avg mini-batch loss: 1.6629142659902572
# [epoch: 7, i:  4299] avg mini-batch loss: 1.7095911186933517
# [epoch: 7, i:  4399] avg mini-batch loss: 1.667224029302597
# [epoch: 7, i:  4499] avg mini-batch loss: 1.7129248034954072
# [epoch: 7, i:  4599] avg mini-batch loss: 1.7440105038881302
# [epoch: 7, i:  4699] avg mini-batch loss: 1.6931201416254043
# [epoch: 7, i:  4799] avg mini-batch loss: 1.8177090686559678
# [epoch: 7, i:  4899] avg mini-batch loss: 1.7021585059165956
# [epoch: 7, i:  4999] avg mini-batch loss: 1.6325095891952515
# [epoch: 7, i:  5099] avg mini-batch loss: 1.6596231478452683
# [epoch: 7, i:  5199] avg mini-batch loss: 1.6938754659891129
# [epoch: 7, i:  5299] avg mini-batch loss: 1.69401174724102
# [epoch: 7, i:  5399] avg mini-batch loss: 1.646719319820404
# [epoch: 7, i:  5499] avg mini-batch loss: 1.6441048407554626
# [epoch: 7, i:  5599] avg mini-batch loss: 1.6578991895914077
# [epoch: 7, i:  5699] avg mini-batch loss: 1.5467905861139297
# [epoch: 7, i:  5799] avg mini-batch loss: 1.6718167704343796
# [epoch: 7, i:  5899] avg mini-batch loss: 1.796174269914627
# [epoch: 7, i:  5999] avg mini-batch loss: 1.6696158742904663
# [epoch: 7, i:  6099] avg mini-batch loss: 1.6468019479513167
# [epoch: 7, i:  6199] avg mini-batch loss: 1.6648734855651854
# [epoch: 7, i:  6299] avg mini-batch loss: 1.7505375611782075
# [epoch: 7, i:  6399] avg mini-batch loss: 1.6414447849988938
# [epoch: 7, i:  6499] avg mini-batch loss: 1.6456219166517259
# [epoch: 7, i:  6599] avg mini-batch loss: 1.5934972375631333
# [epoch: 7, i:  6699] avg mini-batch loss: 1.6470569574832916
# [epoch: 7, i:  6799] avg mini-batch loss: 1.716681500673294
# [epoch: 7, i:  6899] avg mini-batch loss: 1.7929815691709519
# [epoch: 7, i:  6999] avg mini-batch loss: 1.7234175753593446
# [epoch: 7, i:  7099] avg mini-batch loss: 1.6778206366300583
# [epoch: 7, i:  7199] avg mini-batch loss: 1.6661495816707612
# [epoch: 7, i:  7299] avg mini-batch loss: 1.7237001007795334
# [epoch: 7, i:  7399] avg mini-batch loss: 1.65203086912632
# [epoch: 7, i:  7499] avg mini-batch loss: 1.6989845782518387
# [epoch: 7, i:  7599] avg mini-batch loss: 1.6936172097921371
# [epoch: 7, i:  7699] avg mini-batch loss: 1.5878778469562531
# [epoch: 7, i:  7799] avg mini-batch loss: 1.7266537940502167
# [epoch: 7, i:  7899] avg mini-batch loss: 1.7197411447763442
# [epoch: 7, i:  7999] avg mini-batch loss: 1.7100581562519073
# [epoch: 7, i:  8099] avg mini-batch loss: 1.6900922268629075
# [epoch: 7, i:  8199] avg mini-batch loss: 1.7471588516235352
# [epoch: 7, i:  8299] avg mini-batch loss: 1.7799237757921218
# [epoch: 7, i:  8399] avg mini-batch loss: 1.6488274812698365
# [epoch: 7, i:  8499] avg mini-batch loss: 1.7000314229726792
# [epoch: 7, i:  8599] avg mini-batch loss: 1.7150421661138535
# [epoch: 7, i:  8699] avg mini-batch loss: 1.680001916885376
# [epoch: 7, i:  8799] avg mini-batch loss: 1.6175907880067826
# [epoch: 7, i:  8899] avg mini-batch loss: 1.735538777112961
# [epoch: 7, i:  8999] avg mini-batch loss: 1.6197383046150207
# [epoch: 7, i:  9099] avg mini-batch loss: 1.5981620156764984
# [epoch: 7, i:  9199] avg mini-batch loss: 1.6250299870967866
# [epoch: 7, i:  9299] avg mini-batch loss: 1.7473259085416795
# [epoch: 7, i:  9399] avg mini-batch loss: 1.6563658148050309
# [epoch: 7, i:  9499] avg mini-batch loss: 1.6979628163576126
# [epoch: 7, i:  9599] avg mini-batch loss: 1.6321981728076935
# [epoch: 7, i:  9699] avg mini-batch loss: 1.682079509794712
# [epoch: 7, i:  9799] avg mini-batch loss: 1.68033094227314
# [epoch: 7, i:  9899] avg mini-batch loss: 1.6759775459766388
# [epoch: 7, i:  9999] avg mini-batch loss: 1.6199048191308976
# Epoch 00008: reducing learning rate of group 0 to 1.0000e-02.
# Validation Loss:  66558.91459447144
# [epoch: 8, i:    99] avg mini-batch loss: 1.5951356381177901
# [epoch: 8, i:   199] avg mini-batch loss: 1.5407903444767
# [epoch: 8, i:   299] avg mini-batch loss: 1.3954205179214478
# [epoch: 8, i:   399] avg mini-batch loss: 1.5425767552852632
# [epoch: 8, i:   499] avg mini-batch loss: 1.41164053440094
# [epoch: 8, i:   599] avg mini-batch loss: 1.5326067993044854
# [epoch: 8, i:   699] avg mini-batch loss: 1.4308768236637115
# [epoch: 8, i:   799] avg mini-batch loss: 1.379437465071678
# [epoch: 8, i:   899] avg mini-batch loss: 1.4021775442361832
# [epoch: 8, i:   999] avg mini-batch loss: 1.4693438965082168
# [epoch: 8, i:  1099] avg mini-batch loss: 1.420439441204071
# [epoch: 8, i:  1199] avg mini-batch loss: 1.407185632586479
# [epoch: 8, i:  1299] avg mini-batch loss: 1.3996066424250602
# [epoch: 8, i:  1399] avg mini-batch loss: 1.362864886522293
# [epoch: 8, i:  1499] avg mini-batch loss: 1.3804219609498978
# [epoch: 8, i:  1599] avg mini-batch loss: 1.408020176589489
# [epoch: 8, i:  1699] avg mini-batch loss: 1.4176707667112352
# [epoch: 8, i:  1799] avg mini-batch loss: 1.420097615122795
# [epoch: 8, i:  1899] avg mini-batch loss: 1.381991255581379
# [epoch: 8, i:  1999] avg mini-batch loss: 1.4070140397548676
# [epoch: 8, i:  2099] avg mini-batch loss: 1.3662973231077193
# [epoch: 8, i:  2199] avg mini-batch loss: 1.2154772490262986
# [epoch: 8, i:  2299] avg mini-batch loss: 1.3452411639690398
# [epoch: 8, i:  2399] avg mini-batch loss: 1.3398474213480949
# [epoch: 8, i:  2499] avg mini-batch loss: 1.4317732471227647
# [epoch: 8, i:  2599] avg mini-batch loss: 1.352767505645752
# [epoch: 8, i:  2699] avg mini-batch loss: 1.4010210999846457
# [epoch: 8, i:  2799] avg mini-batch loss: 1.4025698018074035
# [epoch: 8, i:  2899] avg mini-batch loss: 1.4190538573265075
# [epoch: 8, i:  2999] avg mini-batch loss: 1.2636431720852852
# [epoch: 8, i:  3099] avg mini-batch loss: 1.4540325045585631
# [epoch: 8, i:  3199] avg mini-batch loss: 1.3743978065252305
# [epoch: 8, i:  3299] avg mini-batch loss: 1.3630373269319533
# [epoch: 8, i:  3399] avg mini-batch loss: 1.2950025314092637
# [epoch: 8, i:  3499] avg mini-batch loss: 1.3817645087838173
# [epoch: 8, i:  3599] avg mini-batch loss: 1.4070913168787955
# [epoch: 8, i:  3699] avg mini-batch loss: 1.3742162257432937
# [epoch: 8, i:  3799] avg mini-batch loss: 1.3533315137028694
# [epoch: 8, i:  3899] avg mini-batch loss: 1.3092954066395759
# [epoch: 8, i:  3999] avg mini-batch loss: 1.4817409574985505
# [epoch: 8, i:  4099] avg mini-batch loss: 1.3332091271877289
# [epoch: 8, i:  4199] avg mini-batch loss: 1.4243225920200349
# [epoch: 8, i:  4299] avg mini-batch loss: 1.3768025237321853
# [epoch: 8, i:  4399] avg mini-batch loss: 1.2988092023134232
# [epoch: 8, i:  4499] avg mini-batch loss: 1.397253331542015
# [epoch: 8, i:  4599] avg mini-batch loss: 1.3747328120470046
# [epoch: 8, i:  4699] avg mini-batch loss: 1.3373134127259254
# [epoch: 8, i:  4799] avg mini-batch loss: 1.3012130242586135
# [epoch: 8, i:  4899] avg mini-batch loss: 1.3323255613446237
# [epoch: 8, i:  4999] avg mini-batch loss: 1.3187105706334115
# [epoch: 8, i:  5099] avg mini-batch loss: 1.2743850713968277
# [epoch: 8, i:  5199] avg mini-batch loss: 1.3035997065901757
# [epoch: 8, i:  5299] avg mini-batch loss: 1.4358242863416673
# [epoch: 8, i:  5399] avg mini-batch loss: 1.401737790107727
# [epoch: 8, i:  5499] avg mini-batch loss: 1.2838290658593179
# [epoch: 8, i:  5599] avg mini-batch loss: 1.4004474180936812
# [epoch: 8, i:  5699] avg mini-batch loss: 1.385816232562065
# [epoch: 8, i:  5799] avg mini-batch loss: 1.323706959784031
# [epoch: 8, i:  5899] avg mini-batch loss: 1.4054975920915604
# [epoch: 8, i:  5999] avg mini-batch loss: 1.3629283118247986
# [epoch: 8, i:  6099] avg mini-batch loss: 1.3178424605727195
# [epoch: 8, i:  6199] avg mini-batch loss: 1.4422163394093515
# [epoch: 8, i:  6299] avg mini-batch loss: 1.19046359449625
# [epoch: 8, i:  6399] avg mini-batch loss: 1.3505645269155502
# [epoch: 8, i:  6499] avg mini-batch loss: 1.4009543633461
# [epoch: 8, i:  6599] avg mini-batch loss: 1.2473323822021485
# [epoch: 8, i:  6699] avg mini-batch loss: 1.3541995480656623
# [epoch: 8, i:  6799] avg mini-batch loss: 1.4017835283279418
# [epoch: 8, i:  6899] avg mini-batch loss: 1.3261050727963448
# [epoch: 8, i:  6999] avg mini-batch loss: 1.3759515964984894
# [epoch: 8, i:  7099] avg mini-batch loss: 1.348610383272171
# [epoch: 8, i:  7199] avg mini-batch loss: 1.3248776245117186
# [epoch: 8, i:  7299] avg mini-batch loss: 1.3553365167975426
# [epoch: 8, i:  7399] avg mini-batch loss: 1.3447373801469802
# [epoch: 8, i:  7499] avg mini-batch loss: 1.3437202125787735
# [epoch: 8, i:  7599] avg mini-batch loss: 1.2729357546567917
# [epoch: 8, i:  7699] avg mini-batch loss: 1.4243962475657463
# [epoch: 8, i:  7799] avg mini-batch loss: 1.343284366428852
# [epoch: 8, i:  7899] avg mini-batch loss: 1.2774404445290566
# [epoch: 8, i:  7999] avg mini-batch loss: 1.2937596726417542
# [epoch: 8, i:  8099] avg mini-batch loss: 1.3920463517308235
# [epoch: 8, i:  8199] avg mini-batch loss: 1.2830582997202873
# [epoch: 8, i:  8299] avg mini-batch loss: 1.42066151201725
# [epoch: 8, i:  8399] avg mini-batch loss: 1.3199040761590004
# [epoch: 8, i:  8499] avg mini-batch loss: 1.2828947186470032
# [epoch: 8, i:  8599] avg mini-batch loss: 1.220423363149166
# [epoch: 8, i:  8699] avg mini-batch loss: 1.3623659831285477
# [epoch: 8, i:  8799] avg mini-batch loss: 1.302337956726551
# [epoch: 8, i:  8899] avg mini-batch loss: 1.2146743208169937
# [epoch: 8, i:  8999] avg mini-batch loss: 1.3944199761748315
# [epoch: 8, i:  9099] avg mini-batch loss: 1.338319008052349
# [epoch: 8, i:  9199] avg mini-batch loss: 1.2980585649609566
# [epoch: 8, i:  9299] avg mini-batch loss: 1.2527340164780616
# [epoch: 8, i:  9399] avg mini-batch loss: 1.3603004205226898
# [epoch: 8, i:  9499] avg mini-batch loss: 1.277106683552265
# [epoch: 8, i:  9599] avg mini-batch loss: 1.3525150939822197
# [epoch: 8, i:  9699] avg mini-batch loss: 1.325598019361496
# [epoch: 8, i:  9799] avg mini-batch loss: 1.26673388004303
# [epoch: 8, i:  9899] avg mini-batch loss: 1.285674656033516
# [epoch: 8, i:  9999] avg mini-batch loss: 1.4004539883136748
# Validation Loss:  69034.23500347137
# [epoch: 9, i:    99] avg mini-batch loss: 1.3350214959681035
# [epoch: 9, i:   199] avg mini-batch loss: 1.233394442498684
# [epoch: 9, i:   299] avg mini-batch loss: 1.2196868500113487
# [epoch: 9, i:   399] avg mini-batch loss: 1.2364899054169656
# [epoch: 9, i:   499] avg mini-batch loss: 1.2245859277248383
# [epoch: 9, i:   599] avg mini-batch loss: 1.2605641190707684
# [epoch: 9, i:   699] avg mini-batch loss: 1.2348351556062698
# [epoch: 9, i:   799] avg mini-batch loss: 1.324951945245266
# [epoch: 9, i:   899] avg mini-batch loss: 1.2333950167894363
# [epoch: 9, i:   999] avg mini-batch loss: 1.1689767131209374
# [epoch: 9, i:  1099] avg mini-batch loss: 1.3430535730719566
# [epoch: 9, i:  1199] avg mini-batch loss: 1.3678323563933372
# [epoch: 9, i:  1299] avg mini-batch loss: 1.2786145186424256
# [epoch: 9, i:  1399] avg mini-batch loss: 1.294546719789505
# [epoch: 9, i:  1499] avg mini-batch loss: 1.1979915830492973
# [epoch: 9, i:  1599] avg mini-batch loss: 1.2572364220023156
# [epoch: 9, i:  1699] avg mini-batch loss: 1.2453696328401564
# [epoch: 9, i:  1799] avg mini-batch loss: 1.280015990138054
# [epoch: 9, i:  1899] avg mini-batch loss: 1.262172032892704
# [epoch: 9, i:  1999] avg mini-batch loss: 1.2562179157137872
# [epoch: 9, i:  2099] avg mini-batch loss: 1.2916938331723213
# [epoch: 9, i:  2199] avg mini-batch loss: 1.1948934657871724
# [epoch: 9, i:  2299] avg mini-batch loss: 1.2859001529216767
# [epoch: 9, i:  2399] avg mini-batch loss: 1.304967891573906
# [epoch: 9, i:  2499] avg mini-batch loss: 1.348306251168251
# [epoch: 9, i:  2599] avg mini-batch loss: 1.2294161647558213
# [epoch: 9, i:  2699] avg mini-batch loss: 1.3626116585731507
# [epoch: 9, i:  2799] avg mini-batch loss: 1.2681290048360825
# [epoch: 9, i:  2899] avg mini-batch loss: 1.2271157586574555
# [epoch: 9, i:  2999] avg mini-batch loss: 1.2701445761322976
# [epoch: 9, i:  3099] avg mini-batch loss: 1.2758547449111939
# [epoch: 9, i:  3199] avg mini-batch loss: 1.1946398144960404
# [epoch: 9, i:  3299] avg mini-batch loss: 1.17815237224102
# [epoch: 9, i:  3399] avg mini-batch loss: 1.1895328196883201
# [epoch: 9, i:  3499] avg mini-batch loss: 1.3687724924087525
# [epoch: 9, i:  3599] avg mini-batch loss: 1.2536163768172264
# [epoch: 9, i:  3699] avg mini-batch loss: 1.2456499691307545
# [epoch: 9, i:  3799] avg mini-batch loss: 1.2996839174628259
# [epoch: 9, i:  3899] avg mini-batch loss: 1.2256803020834923
# [epoch: 9, i:  3999] avg mini-batch loss: 1.2192848855257035
# [epoch: 9, i:  4099] avg mini-batch loss: 1.2320863130688666
# [epoch: 9, i:  4199] avg mini-batch loss: 1.2735418158769607
# [epoch: 9, i:  4299] avg mini-batch loss: 1.2990739139914513
# [epoch: 9, i:  4399] avg mini-batch loss: 1.3122289080917835
# [epoch: 9, i:  4499] avg mini-batch loss: 1.2815055885910989
# [epoch: 9, i:  4599] avg mini-batch loss: 1.2945740500092506
# [epoch: 9, i:  4699] avg mini-batch loss: 1.33375432908535
# [epoch: 9, i:  4799] avg mini-batch loss: 1.3080685836076738
# [epoch: 9, i:  4899] avg mini-batch loss: 1.2016910491883754
# [epoch: 9, i:  4999] avg mini-batch loss: 1.2639838165044786
# [epoch: 9, i:  5099] avg mini-batch loss: 1.232611129283905
# [epoch: 9, i:  5199] avg mini-batch loss: 1.258824741244316
# [epoch: 9, i:  5299] avg mini-batch loss: 1.2568468093127012
# [epoch: 9, i:  5399] avg mini-batch loss: 1.2564790618419648
# [epoch: 9, i:  5499] avg mini-batch loss: 1.2121960079669953
# [epoch: 9, i:  5599] avg mini-batch loss: 1.2342818596959113
# [epoch: 9, i:  5699] avg mini-batch loss: 1.2195025220513345
# [epoch: 9, i:  5799] avg mini-batch loss: 1.1676296889781952
# [epoch: 9, i:  5899] avg mini-batch loss: 1.2341645804047585
# [epoch: 9, i:  5999] avg mini-batch loss: 1.2054053092002868
# [epoch: 9, i:  6099] avg mini-batch loss: 1.3121091502904891
# [epoch: 9, i:  6199] avg mini-batch loss: 1.1932443526387215
# [epoch: 9, i:  6299] avg mini-batch loss: 1.2249768644571304
# [epoch: 9, i:  6399] avg mini-batch loss: 1.3021763584017754
# [epoch: 9, i:  6499] avg mini-batch loss: 1.2963639138638974
# [epoch: 9, i:  6599] avg mini-batch loss: 1.2859150046110153
# [epoch: 9, i:  6699] avg mini-batch loss: 1.2535500821471215
# [epoch: 9, i:  6799] avg mini-batch loss: 1.1450543549656869
# [epoch: 9, i:  6899] avg mini-batch loss: 1.2887046733498573
# [epoch: 9, i:  6999] avg mini-batch loss: 1.1307700960338116
# [epoch: 9, i:  7099] avg mini-batch loss: 1.2182208973169326
# [epoch: 9, i:  7199] avg mini-batch loss: 1.3004555481672286
# [epoch: 9, i:  7299] avg mini-batch loss: 1.3070664517581463
# [epoch: 9, i:  7399] avg mini-batch loss: 1.2509097895026207
# [epoch: 9, i:  7499] avg mini-batch loss: 1.2524967202544213
# [epoch: 9, i:  7599] avg mini-batch loss: 1.2153885942697524
# [epoch: 9, i:  7699] avg mini-batch loss: 1.1923051586747169
# [epoch: 9, i:  7799] avg mini-batch loss: 1.2146297866106033
# [epoch: 9, i:  7899] avg mini-batch loss: 1.3216714653372765
# [epoch: 9, i:  7999] avg mini-batch loss: 1.2123829771578312
# [epoch: 9, i:  8099] avg mini-batch loss: 1.2943000656366348
# [epoch: 9, i:  8199] avg mini-batch loss: 1.2325807368755342
# [epoch: 9, i:  8299] avg mini-batch loss: 1.2009148925542832
# [epoch: 9, i:  8399] avg mini-batch loss: 1.1888246858119964
# [epoch: 9, i:  8499] avg mini-batch loss: 1.2659053048491478
# [epoch: 9, i:  8599] avg mini-batch loss: 1.1680305755138398
# [epoch: 9, i:  8699] avg mini-batch loss: 1.174893989264965
# [epoch: 9, i:  8799] avg mini-batch loss: 1.1633332070708275
# [epoch: 9, i:  8899] avg mini-batch loss: 1.2603299121558666
# [epoch: 9, i:  8999] avg mini-batch loss: 1.2959217983484268
# [epoch: 9, i:  9099] avg mini-batch loss: 1.235772693157196
# [epoch: 9, i:  9199] avg mini-batch loss: 1.184629871547222
# [epoch: 9, i:  9299] avg mini-batch loss: 1.2036150392889977
# [epoch: 9, i:  9399] avg mini-batch loss: 1.2281152185797692
# [epoch: 9, i:  9499] avg mini-batch loss: 1.3111960592865943
# [epoch: 9, i:  9599] avg mini-batch loss: 1.2058051839470862
# [epoch: 9, i:  9699] avg mini-batch loss: 1.2926395589113235
# [epoch: 9, i:  9799] avg mini-batch loss: 1.1238827043771744
# [epoch: 9, i:  9899] avg mini-batch loss: 1.1087301532924174
# [epoch: 9, i:  9999] avg mini-batch loss: 1.2613598673045636
# Validation Loss:  70187.82586574554
# Finished Training.
# LR list:  {0.1, 0.010000000000000002}

# %%
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
plt.plot(valid_losses)
plt.xlabel('epoch')
plt.ylabel('losses')
plt.show()

# %%
# Check several images.
net.eval()
with torch.no_grad():
    dataiter = iter(testloader)
    images, labels = next(dataiter)
    imshow(torchvision.utils.make_grid(images))
    print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
    outputs = net(images.to(device))
    _, predicted = torch.max(outputs, 1)

    print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                                  for j in range(batch_size)))
net.train()
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:    car   car   car   car
# NetMod(
#   (avgpool): AvgPool2d(kernel_size=(8, 8), stride=(8, 8), padding=0)
#   (convinit): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv6): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv7): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv8): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv10): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv12): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv13): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv17): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv18): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
# Get test accuracy.
correct = 0
total = 0

net.eval()
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
#         print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
#         print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
#                               for j in range(batch_size)))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

net.train()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 10 %

# %%
total
# Out:
# 10000

# %%
# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()

        for i in range(batch_size):
            if i == len(labels):
                break
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 60 %
# Accuracy of   car : 69 %
# Accuracy of  bird : 34 %
# Accuracy of   cat : 21 %
# Accuracy of  deer : 51 %
# Accuracy of   dog : 59 %
# Accuracy of  frog : 50 %
# Accuracy of horse : 59 %
# Accuracy of  ship : 67 %
# Accuracy of truck : 80 %
