# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
batch_size = 128
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
     torchvision.transforms.RandomHorizontalFlip(),
     torchvision.transforms.RandomCrop(32, padding=4, padding_mode='constant')])

data = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

train_indices = list(range(len(data)))[:45000]
validation_indices = list(range(len(data)))[45000:]

# train_sample = torch.utils.data.SubsetRandomSampler(train_indices)
# validation_sample = torch.utils.data.SubsetRandomSampler(validation_indices)


# Subsets of the whole train data using the sampled indices
trainset = torch.utils.data.Subset(data, train_indices)
validationset = torch.utils.data.Subset(data, validation_indices)

# Dataloader using the created subsets
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

validationloader = torch.utils.data.DataLoader(validationset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)


testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
len(validationset)
# Out:
# 5000

# %%
print('Train set size: ', len(trainloader) * 4)
print('Validation set size: ', len(validationloader) * 4)
print('Test set size: ', len(testloader) * 4)
# Out:
# Train set size:  1408
# Validation set size:  160
# Test set size:  316

# %%
# The function to show an image.
def imshow(img):
    img = img / 2 + 0.5     # Unnormalize.
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Get some random training images.
dataiter = iter(trainloader)
images, labels = next(dataiter)
# Show images.
imshow(torchvision.utils.make_grid(images))
# Print labels.
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
#  frog plane truck   dog truck horse   dog horse   car  ship  deer  frog  ship  ship  deer   cat  deer truck truck  ship   car truck   cat horse   dog  bird horse  bird   dog   cat  frog   cat plane horse   car  frog   car truck  frog  frog  ship  deer   cat  frog truck  bird   dog  bird   car truck  bird   dog   cat plane  deer truck  ship  ship   car  deer  ship  ship  deer  frog   dog   car  frog   cat  frog horse horse plane  deer truck   car  bird truck plane  frog truck   car  bird   car   car  frog  ship   dog truck   car horse   cat   cat horse  deer plane horse horse  bird horse   car  bird truck  frog horse   cat   car horse  ship  frog  frog   dog   dog  deer horse  deer   cat  ship   car  frog  ship plane plane horse   car  frog horse   car plane

# %%
# Get some random valldation images.
dataiter = iter(validationloader)
images, labels = next(dataiter)
# Show images.
imshow(torchvision.utils.make_grid(images))
# Print labels.
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
#   cat  frog  bird  deer truck   dog  frog   dog   car  ship   car truck truck  deer truck  ship plane horse   car  bird plane  ship  frog  frog   cat   dog truck truck   car  frog  deer horse plane   car   car  ship  ship   dog   cat horse truck  frog   dog   dog   car  deer   cat  deer   cat plane horse truck  bird   dog  bird horse  deer  deer truck horse   dog   car  bird   cat horse   car   car  deer truck  frog   cat horse  deer   dog   dog  deer truck plane  ship plane truck horse   cat plane  ship  bird   cat   dog plane plane  bird  deer horse  frog   cat   dog   dog truck   car  ship plane  frog truck truck   dog  frog  frog horse plane plane truck  bird   car   car   dog   dog   car   dog   dog   car horse  deer   cat horse  frog  ship plane   car

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %%
class ResNetMod(nn.Module):
    def __init__(self):
        super(ResNetMod, self).__init__()
        self.avgpool = nn.AvgPool2d(kernel_size=(8,8))
        
        self.filter1 = 16
        self.filter2 = 32
        self.filter3 = 64
        
        self.convinit = nn.Conv2d(in_channels=3, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        
        self.conv1 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.conv5 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter1, kernel_size=3, stride=1, padding=1)
        self.projection1 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter2, kernel_size=1, stride=2)
        
        self.conv7 = nn.Conv2d(in_channels=self.filter1, out_channels=self.filter2, kernel_size=3, stride=2, padding=1)
        self.conv8 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter2, kernel_size=3, stride=1, padding=1)
        self.conv9 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter2, kernel_size=3, stride=1, padding=1)
        self.conv10 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter2, kernel_size=3, stride=1, padding=1)
        self.conv11 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter2, kernel_size=3, stride=1, padding=1)
        self.conv12 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter2, kernel_size=3, stride=1, padding=1)
        self.projection2 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter3, kernel_size=1, stride=2)
        
        self.conv13 = nn.Conv2d(in_channels=self.filter2, out_channels=self.filter3, kernel_size=3, stride=2, padding=1)
        self.conv14 = nn.Conv2d(in_channels=self.filter3, out_channels=self.filter3, kernel_size=3, stride=1, padding=1)
        self.conv15 = nn.Conv2d(in_channels=self.filter3, out_channels=self.filter3, kernel_size=3, stride=1, padding=1)
        self.conv16 = nn.Conv2d(in_channels=self.filter3, out_channels=self.filter3, kernel_size=3, stride=1, padding=1)
        self.conv17 = nn.Conv2d(in_channels=self.filter3, out_channels=self.filter3, kernel_size=3, stride=1, padding=1)
        self.conv18 = nn.Conv2d(in_channels=self.filter3, out_channels=self.filter3, kernel_size=3, stride=1, padding=1)
        
        self.batchnorminit = nn.BatchNorm2d(self.filter1)
        self.batchnorm1 = nn.BatchNorm2d(self.filter1)
        self.batchnorm2 = nn.BatchNorm2d(self.filter1)
        self.batchnorm3 = nn.BatchNorm2d(self.filter1)
        self.batchnorm4 = nn.BatchNorm2d(self.filter1)
        self.batchnorm5 = nn.BatchNorm2d(self.filter1)
        self.batchnorm6 = nn.BatchNorm2d(self.filter1)
        self.batchnorm7 = nn.BatchNorm2d(self.filter2)
        self.batchnorm8 = nn.BatchNorm2d(self.filter2)
        self.batchnorm9 = nn.BatchNorm2d(self.filter2)
        self.batchnorm10 = nn.BatchNorm2d(self.filter2)
        self.batchnorm11 = nn.BatchNorm2d(self.filter2)
        self.batchnorm12 = nn.BatchNorm2d(self.filter2)
        self.batchnorm13 = nn.BatchNorm2d(self.filter3)
        self.batchnorm14 = nn.BatchNorm2d(self.filter3)
        self.batchnorm15 = nn.BatchNorm2d(self.filter3)
        self.batchnorm16 = nn.BatchNorm2d(self.filter3)
        self.batchnorm17 = nn.BatchNorm2d(self.filter3)
        self.batchnorm18 = nn.BatchNorm2d(self.filter3)
        
        self.fc1 = nn.Linear(in_features=self.filter3, out_features=10)
        
    def forward(self, x):
        ##### n = 3
        ##### first 3x3 conv layer
        x = self.convinit(x)
        x = self.batchnorminit(x)
        x = F.relu(x)
        
        ##### 2n layers for 32x32 features
        x1 = self.conv1(x)
        x1 = self.batchnorm1(x1)
        x1 = F.relu(x1)
        
        x2 = self.conv2(x1)
        x2 = self.batchnorm2(x2)
        x2 = x2 + x
        x2 = F.relu(x2)
        
        x3 = self.conv3(x2)
        x3 = self.batchnorm3(x3)
        x3 = F.relu(x3)
        
        x4 = self.conv4(x3)
        x4 = self.batchnorm4(x4)
        x4 = x4 + x2
        x4 = F.relu(x4)
        
        x5 = self.conv5(x4)
        x5 = self.batchnorm5(x5)
        x5 = F.relu(x5)
        
        x6 = self.conv6(x5)
        x6 = self.batchnorm6(x6)
        x6 = x6 + x4
        x6 = F.relu(x6)
        
        ##### 2n layers for 16x16 features
        x7 = self.conv7(x6)
        x7 = self.batchnorm7(x7)
        x7 = F.relu(x7)
        
        x8 = self.conv8(x7)
        x8 = self.batchnorm8(x8)
        x8 = x8 + self.projection1(x6)
        x8 = F.relu(x8)
        
        x9 = self.conv9(x8)
        x9 = self.batchnorm9(x9)
        x9 = F.relu(x9)
        
        x10 = self.conv10(x9)
        x10 = self.batchnorm10(x10)
        x10 = x10 + x8
        x10 = F.relu(x10)
        
        x11 = self.conv11(x10)
        x11 = self.batchnorm11(x11)
        x11 = F.relu(x11)
        
        x12 = self.conv12(x11)
        x12 = self.batchnorm12(x12)
        x12 = x12 + x10
        x12 = F.relu(x12)
        
        #### 2n layers for 8x8 features
        x13 = self.conv13(x12)
        x13 = self.batchnorm13(x13)
        x13 = F.relu(x13)
        
        x14 = self.conv14(x13)
        x14 = self.batchnorm14(x14)
        x14 = x14 + self.projection2(x12)
        x14 = F.relu(x14)
        
        x15 = self.conv15(x14)
        x15 = self.batchnorm15(x15)
        x15 = F.relu(x15)
        
        x16 = self.conv16(x15)
        x16 = self.batchnorm16(x16)
        x16 = x16 + x14
        x16 = F.relu(x16)
        
        x17 = self.conv17(x16)
        x17 = self.batchnorm17(x17)
        x17 = F.relu(x17)
        
        x18 = self.conv18(x17)
        x18 = self.batchnorm18(x18)
        x18 = x18 + x16
        x18 = F.relu(x18)
        
        # avg pool and linear layer
        x19 = self.avgpool(x18)
        x19 = torch.flatten(x19, 1)
        x19 = self.fc1(x19)
        return x19

resNet = ResNetMod()     # Create the network instance.
resNet.to(device)        # Move the network parameters to the specified device.
# Out:
# ResNetMod(
#   (avgpool): AvgPool2d(kernel_size=(8, 8), stride=(8, 8), padding=0)
#   (convinit): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv6): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (projection1): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2))
#   (conv7): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv8): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv10): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv12): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (projection2): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#   (conv13): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv17): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv18): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorminit): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm11): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm12): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm14): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm16): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm17): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm18): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
class AlexNetMod(nn.Module):
    def __init__(self):
        super(AlexNetMod, self).__init__()
        self.pool = nn.MaxPool2d(kernel_size=(2,2))
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=96, kernel_size=3, stride=1, padding=1)
        self.batchnorm1 = nn.BatchNorm2d(96)
        self.conv2 = nn.Conv2d(in_channels=96, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.batchnorm2 = nn.BatchNorm2d(256)
        self.conv3 = nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=1)
        self.batchnorm3 = nn.BatchNorm2d(384)
        self.conv4 = nn.Conv2d(in_channels=384, out_channels=384, kernel_size=3, stride=1, padding=1)
        self.batchnorm4 = nn.BatchNorm2d(384)
        self.conv5 = nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, stride=1, padding=1)
        self.batchnorm5 = nn.BatchNorm2d(256)
        self.fc1 = nn.Linear(in_features=256, out_features=256)
        self.fc2 = nn.Linear(in_features=256, out_features=256)
        self.fc3 = nn.Linear(in_features=256, out_features=10)
        
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.batchnorm1(x)
        x = self.pool(F.relu(self.conv2(x)))
        x = self.batchnorm2(x)
        x = self.pool(F.relu(self.conv3(x)))
        x = self.batchnorm3(x)
        x = self.pool(F.relu(self.conv4(x)))
        x = self.batchnorm4(x)
        x = self.pool(F.relu(self.conv5(x)))
        x = self.batchnorm5(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.fc2(F.relu(x))
        x = self.fc3(F.relu(x))
        x = F.relu(x)
        return x
    
alexNet = AlexNetMod()     # Create the network instance.
alexNet.to(device)         # Move the network parameters to the specified device.
# Out:
# AlexNetMod(
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv1): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=256, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
class Ensemble(nn.Module):
    def __init__(self, resnet, alexnet):
        super(Ensemble, self).__init__()
        self.resnet = resnet
        self.alexnet = alexnet
        self.fc1 = nn.Linear(in_features=20, out_features=10)
        
    def forward(self, x):
        out1 = self.resnet(x)
        out2 = self.alexnet(x)
        out3 = torch.cat((out1, out2), dim=1)
        out3 = self.fc1(out3)
        
        return out3
    
ensemble = Ensemble(resNet, alexNet)     # Create the network instance.
ensemble.to(device)                       # Move the network parameters to the specified device.
# Out:
# Ensemble(
#   (resnet): ResNetMod(
#     (avgpool): AvgPool2d(kernel_size=(8, 8), stride=(8, 8), padding=0)
#     (convinit): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv4): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv5): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv6): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (projection1): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2))
#     (conv7): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (conv8): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv10): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv12): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (projection2): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2))
#     (conv13): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (conv14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv17): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv18): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorminit): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm11): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm12): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm14): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm16): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm17): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm18): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (fc1): Linear(in_features=64, out_features=10, bias=True)
#   )
#   (alexnet): AlexNetMod(
#     (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (conv1): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm3): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (fc1): Linear(in_features=256, out_features=256, bias=True)
#     (fc2): Linear(in_features=256, out_features=256, bias=True)
#     (fc3): Linear(in_features=256, out_features=10, bias=True)
#   )
#   (fc1): Linear(in_features=20, out_features=10, bias=True)
# )

# %% [markdown]
# # ResNet Training

# %%
epochs = 20       # Total epochs.

# %%
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss()  
# We use stochastic gradient descent (SGD) as optimizer.
opt = optim.SGD(resNet.parameters(), lr=0.1, momentum=0.9, weight_decay=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, mode='min', patience=2, threshold=0.01, min_lr=0.00001, verbose=True)

avg_losses = []   # Avg. losses.
print_freq = 100  # Print frequency.
lr_list = set()
valid_losses = []
train_losses = []

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_loss = 0.0       # Initialize running loss.
    validation_loss = 0.0
    train_loss = 0.0
    
    resNet.train()
    for i, data in enumerate(trainloader, 0):
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step.
        outputs = resNet(inputs)
        loss = loss_func(outputs, labels)
        
        # Backward step.
        loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()

        # Print statistics.
        running_loss += loss.item()
        train_loss += loss.item()
        if i % print_freq == print_freq - 1: # Print every several mini-batches.
            avg_loss = running_loss / print_freq    
            print('[epoch: {}, i: {:5d}] avg mini-batch loss: {}'.format(
                epoch, i, avg_loss))
            avg_losses.append(avg_loss)
            running_loss = 0.0

    resNet.eval()
    with torch.no_grad():
        for i, data in enumerate(validationloader, 0):
            # Get the inputs.
            inputs, labels = data

            # Move the inputs to the specified device.
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward step.
            outputs = resNet(inputs)
            loss = loss_func(outputs, labels)
            validation_loss += loss.item()
    resNet.train()
    
    # If validation error no longer improve, divide the lr by 10
    scheduler.step(validation_loss)
    print('Validation Loss: ', validation_loss, '----', 'Train Loss: ', train_loss)
    valid_losses.append(validation_loss)
    train_losses.append(train_loss)
    lr_list.add(scheduler._last_lr[0])
                            

print('Finished Training.')
print('LR list: ', lr_list)
# Out:
# [epoch: 0, i:    99] avg mini-batch loss: 1.9949089503288269
# [epoch: 0, i:   199] avg mini-batch loss: 1.7766008019447326
# [epoch: 0, i:   299] avg mini-batch loss: 1.6197330915927888
# Validation Loss:  61.70542931556702 ---- Train Loss:  618.7941184043884
# [epoch: 1, i:    99] avg mini-batch loss: 1.4917113554477692
# [epoch: 1, i:   199] avg mini-batch loss: 1.3503830814361573
# [epoch: 1, i:   299] avg mini-batch loss: 1.2783668088912963
# Validation Loss:  55.509310364723206 ---- Train Loss:  475.75095999240875
# [epoch: 2, i:    99] avg mini-batch loss: 1.1551919931173324
# [epoch: 2, i:   199] avg mini-batch loss: 1.0756808215379714
# [epoch: 2, i:   299] avg mini-batch loss: 1.0574946624040604
# Validation Loss:  43.674543261528015 ---- Train Loss:  380.66905266046524
# [epoch: 3, i:    99] avg mini-batch loss: 0.969143972992897
# [epoch: 3, i:   199] avg mini-batch loss: 0.9251154953241348
# [epoch: 3, i:   299] avg mini-batch loss: 0.897133896946907
# Validation Loss:  40.41606414318085 ---- Train Loss:  323.5498948097229
# [epoch: 4, i:    99] avg mini-batch loss: 0.8214179527759552
# [epoch: 4, i:   199] avg mini-batch loss: 0.7959203910827637
# [epoch: 4, i:   299] avg mini-batch loss: 0.7672730606794357
# Validation Loss:  35.73747318983078 ---- Train Loss:  277.69099456071854
# [epoch: 5, i:    99] avg mini-batch loss: 0.739569411277771
# [epoch: 5, i:   199] avg mini-batch loss: 0.7048069560527801
# [epoch: 5, i:   299] avg mini-batch loss: 0.692132793366909
# Validation Loss:  32.57481163740158 ---- Train Loss:  249.92149057984352
# [epoch: 6, i:    99] avg mini-batch loss: 0.6404658460617065
# [epoch: 6, i:   199] avg mini-batch loss: 0.6482309535145759
# [epoch: 6, i:   299] avg mini-batch loss: 0.652478289604187
# Validation Loss:  28.280363738536835 ---- Train Loss:  227.32568421959877
# [epoch: 7, i:    99] avg mini-batch loss: 0.5913815465569496
# [epoch: 7, i:   199] avg mini-batch loss: 0.6117477181553841
# [epoch: 7, i:   299] avg mini-batch loss: 0.5957173830270768
# Validation Loss:  25.136973410844803 ---- Train Loss:  209.98002976179123
# [epoch: 8, i:    99] avg mini-batch loss: 0.555650874376297
# [epoch: 8, i:   199] avg mini-batch loss: 0.5697960585355759
# [epoch: 8, i:   299] avg mini-batch loss: 0.5449418514966965
# Validation Loss:  23.072725117206573 ---- Train Loss:  196.9276666343212
# [epoch: 9, i:    99] avg mini-batch loss: 0.5235471439361572
# [epoch: 9, i:   199] avg mini-batch loss: 0.5442297026515007
# [epoch: 9, i:   299] avg mini-batch loss: 0.5267538952827454
# Validation Loss:  24.7623071372509 ---- Train Loss:  186.75424921512604
# [epoch: 10, i:    99] avg mini-batch loss: 0.5132370933890342
# [epoch: 10, i:   199] avg mini-batch loss: 0.504627773463726
# [epoch: 10, i:   299] avg mini-batch loss: 0.5145935392379761
# Validation Loss:  24.773838877677917 ---- Train Loss:  179.57824471592903
# [epoch: 11, i:    99] avg mini-batch loss: 0.4857982984185219
# [epoch: 11, i:   199] avg mini-batch loss: 0.4963302356004715
# [epoch: 11, i:   299] avg mini-batch loss: 0.48749583810567854
# Epoch 00012: reducing learning rate of group 0 to 1.0000e-02.
# Validation Loss:  23.631957411766052 ---- Train Loss:  171.5701779127121
# [epoch: 12, i:    99] avg mini-batch loss: 0.406596357524395
# [epoch: 12, i:   199] avg mini-batch loss: 0.3779558390378952
# [epoch: 12, i:   299] avg mini-batch loss: 0.3528327852487564
# Validation Loss:  15.997119307518005 ---- Train Loss:  130.91353258490562
# [epoch: 13, i:    99] avg mini-batch loss: 0.344340962767601
# [epoch: 13, i:   199] avg mini-batch loss: 0.3272995935380459
# [epoch: 13, i:   299] avg mini-batch loss: 0.3450876687467098
# Validation Loss:  15.212788291275501 ---- Train Loss:  118.79845935106277
# [epoch: 14, i:    99] avg mini-batch loss: 0.32845452830195426
# [epoch: 14, i:   199] avg mini-batch loss: 0.3235135065019131
# [epoch: 14, i:   299] avg mini-batch loss: 0.33416097328066824
# Validation Loss:  15.43957394361496 ---- Train Loss:  116.01216815412045
# [epoch: 15, i:    99] avg mini-batch loss: 0.31308628618717194
# [epoch: 15, i:   199] avg mini-batch loss: 0.32061905205249785
# [epoch: 15, i:   299] avg mini-batch loss: 0.30882446601986885
# Validation Loss:  15.191678941249847 ---- Train Loss:  111.18609608709812
# [epoch: 16, i:    99] avg mini-batch loss: 0.30291828617453576
# [epoch: 16, i:   199] avg mini-batch loss: 0.30531886622309684
# [epoch: 16, i:   299] avg mini-batch loss: 0.31345189720392225
# Validation Loss:  14.717289119958878 ---- Train Loss:  108.35729467868805
# [epoch: 17, i:    99] avg mini-batch loss: 0.2970134861767292
# [epoch: 17, i:   199] avg mini-batch loss: 0.3117329266667366
# [epoch: 17, i:   299] avg mini-batch loss: 0.3064986480772495
# Validation Loss:  15.16795402765274 ---- Train Loss:  107.98164710402489
# [epoch: 18, i:    99] avg mini-batch loss: 0.2913300363719463
# [epoch: 18, i:   199] avg mini-batch loss: 0.3035755370557308
# [epoch: 18, i:   299] avg mini-batch loss: 0.3001167558133602
# Validation Loss:  15.422814473509789 ---- Train Loss:  105.0919186770916
# [epoch: 19, i:    99] avg mini-batch loss: 0.28445604026317595
# [epoch: 19, i:   199] avg mini-batch loss: 0.2910572011768818
# [epoch: 19, i:   299] avg mini-batch loss: 0.29885550260543825
# Epoch 00020: reducing learning rate of group 0 to 1.0000e-03.
# Validation Loss:  14.78530378639698 ---- Train Loss:  102.78230130672455
# Finished Training.
# LR list:  {0.1, 0.010000000000000002, 0.0010000000000000002}

# %%
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
plt.plot(valid_losses)
plt.xlabel('epoch')
plt.ylabel('losses')
plt.show()

# %%
plt.plot(train_losses)
plt.xlabel('epoch')
plt.ylabel('losses')
plt.show()

# %%
# Get test accuracy.
correct = 0
total = 0

resNet.eval()
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = resNet(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

resNet.train()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 86 %

# %%
# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = resNet(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()

        for i in range(batch_size):
            if i == len(labels):
                break
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 88 %
# Accuracy of   car : 94 %
# Accuracy of  bird : 79 %
# Accuracy of   cat : 72 %
# Accuracy of  deer : 85 %
# Accuracy of   dog : 77 %
# Accuracy of  frog : 91 %
# Accuracy of horse : 87 %
# Accuracy of  ship : 90 %
# Accuracy of truck : 91 %

# %% [markdown]
# # AlexNet Training

# %%
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss()  
# We use stochastic gradient descent (SGD) as optimizer.
opt = optim.SGD(alexNet.parameters(), lr=0.001, momentum=0.9, weight_decay=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, mode='min', patience=2, threshold=0.01, verbose=True)

avg_losses = []   # Avg. losses.
valid_losses = []
train_losses = []
print_freq = 100  # Print frequency.
lr_list = set()

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_loss = 0.0       # Initialize running loss.
    validation_loss = 0.0
    train_loss = 0.0
    
    alexNet.train()
    for i, data in enumerate(trainloader, 0):
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step.
        outputs = alexNet(inputs)
        loss = loss_func(outputs, labels)
        
        # Backward step.
        loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()

        # Print statistics.
        running_loss += loss.item()
        train_loss += loss.item()
        
        if i % print_freq == print_freq - 1: # Print every several mini-batches.
            avg_loss = running_loss / print_freq    
            print('[epoch: {}, i: {:5d}] avg mini-batch loss: {}'.format(
                epoch, i, avg_loss))
            avg_losses.append(avg_loss)
            running_loss = 0.0

    alexNet.eval()
    with torch.no_grad():
        for i, data in enumerate(validationloader, 0):
            # Get the inputs.
            inputs, labels = data

            # Move the inputs to the specified device.
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward step.
            outputs = alexNet(inputs)
            loss = loss_func(outputs, labels)
            validation_loss += loss.item()
    alexNet.train()
    
    # If validation error no longer improve, divide the lr by 10
    scheduler.step(validation_loss)
    print('Validation Loss: ', validation_loss, '----', 'Train Loss: ', train_loss)
    valid_losses.append(validation_loss)
    train_losses.append(train_loss)
    lr_list.add(scheduler._last_lr[0])
                            

print('Finished Training.')
print('LR list: ', lr_list)
# Out:
# [epoch: 0, i:    99] avg mini-batch loss: 2.2224481296539307
# [epoch: 0, i:   199] avg mini-batch loss: 2.032303447723389
# [epoch: 0, i:   299] avg mini-batch loss: 1.8684511935710908
# Validation Loss:  69.24034762382507 ---- Train Loss:  705.8447935581207
# [epoch: 1, i:    99] avg mini-batch loss: 1.718330453634262
# [epoch: 1, i:   199] avg mini-batch loss: 1.651219803094864
# [epoch: 1, i:   299] avg mini-batch loss: 1.6028993463516235
# Validation Loss:  61.45107388496399 ---- Train Loss:  578.7392851114273
# [epoch: 2, i:    99] avg mini-batch loss: 1.5213598728179931
# [epoch: 2, i:   199] avg mini-batch loss: 1.4948054432868958
# [epoch: 2, i:   299] avg mini-batch loss: 1.4609312629699707
# Validation Loss:  56.95859503746033 ---- Train Loss:  521.8147550821304
# [epoch: 3, i:    99] avg mini-batch loss: 1.400635417699814
# [epoch: 3, i:   199] avg mini-batch loss: 1.3739904284477233
# [epoch: 3, i:   299] avg mini-batch loss: 1.3578617370128632
# Validation Loss:  51.88853061199188 ---- Train Loss:  480.8756910562515
# [epoch: 4, i:    99] avg mini-batch loss: 1.294267544746399
# [epoch: 4, i:   199] avg mini-batch loss: 1.2941905879974365
# [epoch: 4, i:   299] avg mini-batch loss: 1.2800847923755645
# Validation Loss:  49.12498390674591 ---- Train Loss:  453.0914213657379
# [epoch: 5, i:    99] avg mini-batch loss: 1.229403283596039
# [epoch: 5, i:   199] avg mini-batch loss: 1.2173322701454163
# [epoch: 5, i:   299] avg mini-batch loss: 1.2107353186607361
# Validation Loss:  47.099882423877716 ---- Train Loss:  428.7710897922516
# [epoch: 6, i:    99] avg mini-batch loss: 1.1566065514087678
# [epoch: 6, i:   199] avg mini-batch loss: 1.173584250807762
# [epoch: 6, i:   299] avg mini-batch loss: 1.1573208916187285
# Validation Loss:  45.697548031806946 ---- Train Loss:  409.13126385211945
# [epoch: 7, i:    99] avg mini-batch loss: 1.1217863553762435
# [epoch: 7, i:   199] avg mini-batch loss: 1.1218526196479797
# [epoch: 7, i:   299] avg mini-batch loss: 1.102953171133995
# Validation Loss:  45.22356230020523 ---- Train Loss:  392.10489320755005
# [epoch: 8, i:    99] avg mini-batch loss: 1.0804701745510101
# [epoch: 8, i:   199] avg mini-batch loss: 1.0676168805360795
# [epoch: 8, i:   299] avg mini-batch loss: 1.0644066798686982
# Validation Loss:  43.117426335811615 ---- Train Loss:  376.63290494680405
# [epoch: 9, i:    99] avg mini-batch loss: 1.0380102097988129
# [epoch: 9, i:   199] avg mini-batch loss: 1.0389751309156419
# [epoch: 9, i:   299] avg mini-batch loss: 1.0178692197799684
# Validation Loss:  42.10197687149048 ---- Train Loss:  362.7503390312195
# [epoch: 10, i:    99] avg mini-batch loss: 1.0040230232477187
# [epoch: 10, i:   199] avg mini-batch loss: 1.011486696600914
# [epoch: 10, i:   299] avg mini-batch loss: 1.0038120067119598
# Validation Loss:  40.60275477170944 ---- Train Loss:  354.67306250333786
# [epoch: 11, i:    99] avg mini-batch loss: 0.9879748022556305
# [epoch: 11, i:   199] avg mini-batch loss: 0.9761990159749985
# [epoch: 11, i:   299] avg mini-batch loss: 0.9908775246143341
# Validation Loss:  39.548491179943085 ---- Train Loss:  345.28808003664017
# [epoch: 12, i:    99] avg mini-batch loss: 0.9571450608968735
# [epoch: 12, i:   199] avg mini-batch loss: 0.9763586783409118
# [epoch: 12, i:   299] avg mini-batch loss: 0.9492337679862977
# Validation Loss:  38.993783824145794 ---- Train Loss:  338.50535732507706
# [epoch: 13, i:    99] avg mini-batch loss: 0.9326715916395187
# [epoch: 13, i:   199] avg mini-batch loss: 0.9212646210193634
# [epoch: 13, i:   299] avg mini-batch loss: 0.9349279981851578
# Validation Loss:  40.221146285533905 ---- Train Loss:  327.07660841941833
# [epoch: 14, i:    99] avg mini-batch loss: 0.9035157924890518
# [epoch: 14, i:   199] avg mini-batch loss: 0.9201832246780396
# [epoch: 14, i:   299] avg mini-batch loss: 0.9130814224481583
# Validation Loss:  39.3591964840889 ---- Train Loss:  320.47909283638
# [epoch: 15, i:    99] avg mini-batch loss: 0.9007856822013856
# [epoch: 15, i:   199] avg mini-batch loss: 0.8842259186506272
# [epoch: 15, i:   299] avg mini-batch loss: 0.9048270630836487
# Epoch 00016: reducing learning rate of group 0 to 1.0000e-04.
# Validation Loss:  38.955970108509064 ---- Train Loss:  316.168480694294
# [epoch: 16, i:    99] avg mini-batch loss: 0.837580651640892
# [epoch: 16, i:   199] avg mini-batch loss: 0.8191999328136444
# [epoch: 16, i:   299] avg mini-batch loss: 0.8274061191082
# Validation Loss:  36.355578660964966 ---- Train Loss:  291.8687978386879
# [epoch: 17, i:    99] avg mini-batch loss: 0.8199442028999329
# [epoch: 17, i:   199] avg mini-batch loss: 0.829299601316452
# [epoch: 17, i:   299] avg mini-batch loss: 0.8170746278762817
# Validation Loss:  35.987541139125824 ---- Train Loss:  289.24266719818115
# [epoch: 18, i:    99] avg mini-batch loss: 0.8230537712574005
# [epoch: 18, i:   199] avg mini-batch loss: 0.8078272289037705
# [epoch: 18, i:   299] avg mini-batch loss: 0.8190154868364334
# Validation Loss:  36.64023023843765 ---- Train Loss:  286.87587678432465
# [epoch: 19, i:    99] avg mini-batch loss: 0.8198648887872696
# [epoch: 19, i:   199] avg mini-batch loss: 0.800065650343895
# [epoch: 19, i:   299] avg mini-batch loss: 0.8092840865254403
# Validation Loss:  36.97399967908859 ---- Train Loss:  285.00662383437157
# Finished Training.
# LR list:  {0.0001, 0.001}

# %%
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
plt.plot(valid_losses)
plt.xlabel('epoch')
plt.ylabel('losses')
plt.show()

# %%
plt.plot(train_losses)
plt.xlabel('epoch')
plt.ylabel('losses')
plt.show()

# %%
# Get test accuracy.
correct = 0
total = 0

alexNet.eval()
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = alexNet(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

alexNet.train()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 66 %

# %%
# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = alexNet(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()

        for i in range(batch_size):
            if i == len(labels):
                break
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 85 %
# Accuracy of   car : 92 %
# Accuracy of  bird : 79 %
# Accuracy of   cat : 66 %
# Accuracy of  deer : 84 %
# Accuracy of   dog : 75 %
# Accuracy of  frog :  0 %
# Accuracy of horse :  0 %
# Accuracy of  ship : 89 %
# Accuracy of truck : 86 %

# %% [markdown]
# # Ensemble Training

# %%
# We use cross-entropy as loss function.
loss_func = nn.CrossEntropyLoss()  
# We use stochastic gradient descent (SGD) as optimizer.
opt = optim.SGD(ensemble.parameters(), lr=0.1, momentum=0.9, weight_decay=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, mode='min', patience=2, threshold=0.01, verbose=True)

avg_losses = []   # Avg. losses.
valid_losses = []
train_losses = []
print_freq = 100  # Print frequency.
lr_list = set()

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_loss = 0.0       # Initialize running loss.
    validation_loss = 0.0
    train_loss = 0.0
    
    ensemble.train()
    for i, data in enumerate(trainloader, 0):
        # Get the inputs.
        inputs, labels = data
        
        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)
        
        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step.
        outputs = ensemble(inputs)
        loss = loss_func(outputs, labels)
        
        # Backward step.
        loss.backward()
        
        # Optimization step (update the parameters).
        opt.step()

        # Print statistics.
        running_loss += loss.item()
        train_loss += loss.item()
        
        if i % print_freq == print_freq - 1: # Print every several mini-batches.
            avg_loss = running_loss / print_freq    
            print('[epoch: {}, i: {:5d}] avg mini-batch loss: {}'.format(
                epoch, i, avg_loss))
            avg_losses.append(avg_loss)
            running_loss = 0.0

    ensemble.eval()
    with torch.no_grad():
        for i, data in enumerate(validationloader, 0):
            # Get the inputs.
            inputs, labels = data

            # Move the inputs to the specified device.
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward step.
            outputs = ensemble(inputs)
            loss = loss_func(outputs, labels)
            validation_loss += loss.item()
    ensemble.train()
    
    # If validation error no longer improve, divide the lr by 10
    scheduler.step(validation_loss)
    print('Validation Loss: ', validation_loss, '----', 'Train Loss: ', train_loss)
    valid_losses.append(validation_loss)
    train_losses.append(train_loss)
    lr_list.add(scheduler._last_lr[0])
                            

print('Finished Training.')
print('LR list: ', lr_list)
# Out:
# [epoch: 0, i:    99] avg mini-batch loss: 0.7211092564463616
# [epoch: 0, i:   199] avg mini-batch loss: 0.5240585076808929
# [epoch: 0, i:   299] avg mini-batch loss: 0.5232339239120484
# Validation Loss:  39.58475434780121 ---- Train Loss:  205.67862182855606
# [epoch: 1, i:    99] avg mini-batch loss: 0.5523912319540978
# [epoch: 1, i:   199] avg mini-batch loss: 0.5932343435287476
# [epoch: 1, i:   299] avg mini-batch loss: 0.6218385609984398
# Validation Loss:  37.09286439418793 ---- Train Loss:  209.8847914636135
# [epoch: 2, i:    99] avg mini-batch loss: 0.6301137107610703
# [epoch: 2, i:   199] avg mini-batch loss: 0.6328519421815872
# [epoch: 2, i:   299] avg mini-batch loss: 0.6352024346590042
# Validation Loss:  32.79640704393387 ---- Train Loss:  223.31250444054604
# [epoch: 3, i:    99] avg mini-batch loss: 0.6530581837892533
# [epoch: 3, i:   199] avg mini-batch loss: 0.6549473571777343
# [epoch: 3, i:   299] avg mini-batch loss: 0.6505936527252197
# Validation Loss:  33.43045765161514 ---- Train Loss:  231.31951209902763
# [epoch: 4, i:    99] avg mini-batch loss: 0.6440801230072976
# [epoch: 4, i:   199] avg mini-batch loss: 0.6315175786614418
# [epoch: 4, i:   299] avg mini-batch loss: 0.6773589915037155
# Validation Loss:  41.74379026889801 ---- Train Loss:  230.5249665081501
# [epoch: 5, i:    99] avg mini-batch loss: 0.6487747329473496
# [epoch: 5, i:   199] avg mini-batch loss: 0.6579998630285263
# [epoch: 5, i:   299] avg mini-batch loss: 0.6529520305991173
# Epoch 00006: reducing learning rate of group 0 to 1.0000e-02.
# Validation Loss:  38.03904974460602 ---- Train Loss:  230.4023536145687
# [epoch: 6, i:    99] avg mini-batch loss: 0.5077693709731101
# [epoch: 6, i:   199] avg mini-batch loss: 0.4397897970676422
# [epoch: 6, i:   299] avg mini-batch loss: 0.4111281177401543
# Validation Loss:  16.975544720888138 ---- Train Loss:  156.956663236022
# [epoch: 7, i:    99] avg mini-batch loss: 0.3872380527853966
# [epoch: 7, i:   199] avg mini-batch loss: 0.3861320243775845
# [epoch: 7, i:   299] avg mini-batch loss: 0.37892694979906083
# Validation Loss:  15.550880283117294 ---- Train Loss:  134.31674064695835
# [epoch: 8, i:    99] avg mini-batch loss: 0.3493872322142124
# [epoch: 8, i:   199] avg mini-batch loss: 0.3601834627985954
# [epoch: 8, i:   299] avg mini-batch loss: 0.35157540813088417
# Validation Loss:  15.191694289445877 ---- Train Loss:  125.53216230869293
# [epoch: 9, i:    99] avg mini-batch loss: 0.34141296982765196
# [epoch: 9, i:   199] avg mini-batch loss: 0.3435770098865032
# [epoch: 9, i:   299] avg mini-batch loss: 0.34578617379069326
# Validation Loss:  15.322277687489986 ---- Train Loss:  120.94178861379623
# [epoch: 10, i:    99] avg mini-batch loss: 0.3205146639049053
# [epoch: 10, i:   199] avg mini-batch loss: 0.32637416139245035
# [epoch: 10, i:   299] avg mini-batch loss: 0.3323142945766449
# Validation Loss:  15.273759171366692 ---- Train Loss:  114.7845538854599
# [epoch: 11, i:    99] avg mini-batch loss: 0.31907034039497373
# [epoch: 11, i:   199] avg mini-batch loss: 0.3227559478580952
# [epoch: 11, i:   299] avg mini-batch loss: 0.30639995709061624
# Epoch 00012: reducing learning rate of group 0 to 1.0000e-03.
# Validation Loss:  16.08495807647705 ---- Train Loss:  111.58020716905594
# [epoch: 12, i:    99] avg mini-batch loss: 0.2885841719806194
# [epoch: 12, i:   199] avg mini-batch loss: 0.27616641044616697
# [epoch: 12, i:   299] avg mini-batch loss: 0.26710090294480326
# Validation Loss:  13.519294038414955 ---- Train Loss:  97.47824843227863
# [epoch: 13, i:    99] avg mini-batch loss: 0.25793942555785176
# [epoch: 13, i:   199] avg mini-batch loss: 0.2636117045581341
# [epoch: 13, i:   299] avg mini-batch loss: 0.26983381554484365
# Validation Loss:  13.43079924583435 ---- Train Loss:  92.83906023204327
# [epoch: 14, i:    99] avg mini-batch loss: 0.2504471769928932
# [epoch: 14, i:   199] avg mini-batch loss: 0.2561946692317724
# [epoch: 14, i:   299] avg mini-batch loss: 0.2603272910416126
# Validation Loss:  12.899246972054243 ---- Train Loss:  89.65377205610275
# [epoch: 15, i:    99] avg mini-batch loss: 0.25808818995952604
# [epoch: 15, i:   199] avg mini-batch loss: 0.2532779456675053
# [epoch: 15, i:   299] avg mini-batch loss: 0.2540500594675541
# Validation Loss:  12.801620483398438 ---- Train Loss:  89.88336221128702
# [epoch: 16, i:    99] avg mini-batch loss: 0.24511314138770104
# [epoch: 16, i:   199] avg mini-batch loss: 0.25732120797038077
# [epoch: 16, i:   299] avg mini-batch loss: 0.24760506376624108
# Validation Loss:  13.193653066642582 ---- Train Loss:  88.28417161852121
# [epoch: 17, i:    99] avg mini-batch loss: 0.24594062589108945
# [epoch: 17, i:   199] avg mini-batch loss: 0.2536413899064064
# [epoch: 17, i:   299] avg mini-batch loss: 0.24399561911821366
# Epoch 00018: reducing learning rate of group 0 to 1.0000e-04.
# Validation Loss:  12.942346587777138 ---- Train Loss:  86.92916987091303
# [epoch: 18, i:    99] avg mini-batch loss: 0.23966340020298957
# [epoch: 18, i:   199] avg mini-batch loss: 0.24378202825784684
# [epoch: 18, i:   299] avg mini-batch loss: 0.23848672069609164
# Validation Loss:  13.02762634307146 ---- Train Loss:  85.0607410594821
# [epoch: 19, i:    99] avg mini-batch loss: 0.24835907258093357
# [epoch: 19, i:   199] avg mini-batch loss: 0.23945423528552057
# [epoch: 19, i:   299] avg mini-batch loss: 0.23123526990413665
# Validation Loss:  13.376900896430016 ---- Train Loss:  84.27802699804306
# Finished Training.
# LR list:  {0.1, 0.00010000000000000003, 0.010000000000000002, 0.0010000000000000002}

# %%
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
plt.plot(valid_losses)
plt.xlabel('epoch')
plt.ylabel('losses')
plt.show()

# %%
plt.plot(train_losses)
plt.xlabel('epoch')
plt.ylabel('losses')
plt.show()

# %%
# Get test accuracy.
correct = 0
total = 0

ensemble.eval()
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = ensemble(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

ensemble.train()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 88 %

# %%
# Get test accuracy for each class.
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = ensemble(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()

        for i in range(batch_size):
            if i == len(labels):
                break
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 89 %
# Accuracy of   car : 94 %
# Accuracy of  bird : 81 %
# Accuracy of   cat : 74 %
# Accuracy of  deer : 88 %
# Accuracy of   dog : 81 %
# Accuracy of  frog : 90 %
# Accuracy of horse : 90 %
# Accuracy of  ship : 91 %
# Accuracy of truck : 91 %
